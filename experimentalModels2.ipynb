# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Train

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Create a DataFrame with your expanded dataset
data = pd.DataFrame({
    'Week': [1, 2, 1, 2],
    'Player': ['J', 'A', 'A', 'J'],
    'Pts': [15, 17, 19, 25],
    'Yds': [120, 80, 150, 100],  # Example Yds values
    'Tds': [2, 1, 3, 2]  # Example Tds values
})

# Convert categorical 'Player' variable into numerical using one-hot encoding
data = pd.get_dummies(data, columns=['Player'])

# Separate the dataset into features (X) and the target variable (y)
X = data.drop(['Pts', 'Yds', 'Tds'], axis=1)  # Keep 'Player' and 'Week' for prediction
y = data[['Pts', 'Yds', 'Tds']]  # Predict multiple columns

# Create and train a linear regression model for each target variable
models = {}
for target in y.columns:
    model = LinearRegression()
    model.fit(X, y[target])
    models[target] = model

data.head(10)
# Out:
#    Week  Pts  Yds  Tds  Player_A  Player_J
# 0     1   15  120    2     False      True
# 1     2   17   80    1      True     False
# 2     1   19  150    3      True     False
# 3     2   25  100    2     False      True

# %% [markdown]
# Predict

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Create a DataFrame with your expanded dataset
data = pd.DataFrame({
    'Week': [1, 2, 1, 2],
    'Player': ['J', 'B', 'B', 'J'],
    'Pts': [15, 17, 19, 25],
    'Yds': [120, 80, 150, 100],  # Example Yds values
    'Tds': [2, 1, 3, 2]  # Example Tds values
})

df = data
# Convert categorical 'Player' variable into numerical using one-hot encoding
data = pd.get_dummies(data, columns=['Player'], drop_first=False)

# Separate the dataset into features (X) and the target variable (y)
X = data.drop(['Pts', 'Yds', 'Tds'], axis=1)
y = data[['Pts', 'Yds', 'Tds']]

# Create and train a linear regression model for each player and each target variable
player_models = {}
for player in df['Player'].unique():
    player_data = data[data['Player_' + player] == 1]
    X_player = player_data.drop(['Pts', 'Yds', 'Tds'], axis=1)
    y_player = player_data[['Pts', 'Yds', 'Tds']]
    
    models = {}
    for target in y.columns:
        model = LinearRegression()
        model.fit(X_player, y_player[target])
        models[target] = model
    
    player_models[player] = models

# Now, you can make predictions for week 3 with the new features for each player
week3_data = pd.DataFrame({
    'Week': [3],
    'Player_B': [1],  # Set the corresponding player's column to 1, and others to 0 for prediction
    'Player_J': [0],  # Ensure the player columns match those from training data
})

predicted_data_week3 = {}
for player in df['Player'].unique():
    predictions = {}
    for target in y.columns:
        predictions[target] = player_models[player][target].predict(week3_data)[0]
    predicted_data_week3[player] = predictions

# Print the predictions for each player and each target variable
print("Predicted Data for Week 3:")
for player in df['Player'].unique():
    print(f"Player {player}:")
    for target, value in predicted_data_week3[player].items():
        print(f"{target}: {value:.2f}")
# Out:
# Predicted Data for Week 3:
# Player J:
# Pts: 35.00
# Yds: 80.00
# Tds: 2.00
# Player B:
# Pts: 15.00
# Yds: 10.00
# Tds: -1.00

# %% [markdown]
# ## Random Forest with GridSearchCV hyperparemeter tuning and no regularization

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer

# Load your dataset
data = pd.read_csv("datasets/weekly_scoring.csv")

# Preprocessing
data = data[data['POS'] == 'qb']
data = data.drop(columns=['POS', 'MISC G', 'MISC ROST', 'RECEIVING REC', 'RECEIVING TGT', 'RECEIVING YDS', 'RECEIVING Y/R',
 'RECEIVING LG', 'RECEIVING 20+', 'RECEIVING TD', 'RUSHING Y/A', 'RUSHING LG',
 'RUSHING 20+'])
data = pd.get_dummies(data, columns=['PLAYER'], drop_first=False)

# Identify columns with missing values before imputation
columns_with_missing = data.columns[data.isnull().any()].tolist()

# Impute missing values with the mean of each column
imputer = SimpleImputer(strategy='mean')
data = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# Define the list of variables to predict
var_list = ['PASSING CMP', 'PASSING ATT', 'PASSING PCT', 'PASSING YDS', 'PASSING Y/A', 'PASSING TD', 'PASSING INT',
            'PASSING SACKS', 'RUSHING ATT', 'RUSHING YDS', 'RUSHING TD', 'MISC FL', 'MISC FPTS', 'MISC FPTS/G', 'WEEK ']

# Separate the dataset into features (X) and the target variable (y)
X = data.drop(var_list, axis=1)
y = data[var_list]

# Save a copy of the dataset
df = data

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X, y)

# Fit the model with the best hyperparameters
best_rf_model = grid_search.best_estimator_
best_rf_model.fit(X, y)

# Initialize a DataFrame with zeros
week6_data = pd.DataFrame(0, index=range(1), columns=X.columns)

print("Predicted Points for Week 6:")
for player in week6_data.columns:
    # Clean the player name by removing special characters, spaces, and parentheses
    # player_cleaned = ''.join(e for e in player if (e.isalnum() or e.isspace()))
    week6_data[player] = 1  # Set the corresponding player's column to 1 for prediction
    predictions = best_rf_model.predict(week6_data)
    
    for i, column in enumerate(var_list):
        prediction = predictions[0][i]
        print(f"Player {player}, {column}: {prediction:.2f}")
    week6_data[player] = 0
# Out:
# Predicted Points for Week 6:
# Player POS RANK, PASSING CMP: 26.75
# Player POS RANK, PASSING ATT: 37.82
# Player POS RANK, PASSING PCT: 70.51
# Player POS RANK, PASSING YDS: 351.25
# Player POS RANK, PASSING Y/A: 9.54
# Player POS RANK, PASSING TD: 3.02
# Player POS RANK, PASSING INT: 0.48
# Player POS RANK, PASSING SACKS: 1.58
# Player POS RANK, RUSHING ATT: 5.37
# Player POS RANK, RUSHING YDS: 25.79
# Player POS RANK, RUSHING TD: 0.40
# Player POS RANK, MISC FL: 0.26
# Player POS RANK, MISC FPTS: 30.24
# Player POS RANK, MISC FPTS/G: 30.24
# Player POS RANK, WEEK : 2.96
# Player PLAYER_AJ McCarron (CIN), PASSING CMP: 26.75
# Player PLAYER_AJ McCarron (CIN), PASSING ATT: 37.82
# Player PLAYER_AJ McCarron (CIN), PASSING PCT: 70.51
# Player PLAYER_AJ McCarron (CIN), PASSING YDS: 351.25
# Player PLAYER_AJ McCarron (CIN), PASSING Y/A: 9.54
# Player PLAYER_AJ McCarron (CIN), PASSING TD: 3.02
# Player PLAYER_AJ McCarron (CIN), PASSING INT: 0.48
# Player PLAYER_AJ McCarron (CIN), PASSING SACKS: 1.58
# Player PLAYER_AJ McCarron (CIN), RUSHING ATT: 5.37
# Player PLAYER_AJ McCarron (CIN), RUSHING YDS: 25.79
# Player PLAYER_AJ McCarron (CIN), RUSHING TD: 0.40
# Player PLAYER_AJ McCarron (CIN), MISC FL: 0.26
# Player PLAYER_AJ McCarron (CIN), MISC FPTS: 30.24
# Player PLAYER_AJ McCarron (CIN), MISC FPTS/G: 30.24
# Player PLAYER_AJ McCarron (CIN), WEEK : 2.96
# Player PLAYER_Aaron Rodgers (NYJ), PASSING CMP: 26.75
# Player PLAYER_Aaron Rodgers (NYJ), PASSING ATT: 37.82
# Player PLAYER_Aaron Rodgers (NYJ), PASSING PCT: 70.51
# Player PLAYER_Aaron Rodgers (NYJ), PASSING YDS: 351.25
# Player PLAYER_Aaron Rodgers (NYJ), PASSING Y/A: 9.54
# Player PLAYER_Aaron Rodgers (NYJ), PASSING TD: 3.02
# Player PLAYER_Aaron Rodgers (NYJ), PASSING INT: 0.48
# Player PLAYER_Aaron Rodgers (NYJ), PASSING SACKS: 1.58
# Player PLAYER_Aaron Rodgers (NYJ), RUSHING ATT: 5.37
# Player PLAYER_Aaron Rodgers (NYJ), RUSHING YDS: 25.79
# Player PLAYER_Aaron Rodgers (NYJ), RUSHING TD: 0.40
# Player PLAYER_Aaron Rodgers (NYJ), MISC FL: 0.26
# Player PLAYER_Aaron Rodgers (NYJ), MISC FPTS: 30.24
# Player PLAYER_Aaron Rodgers (NYJ), MISC FPTS/G: 30.24
# Player PLAYER_Aaron Rodgers (NYJ), WEEK : 2.96
# Player PLAYER_Adam Froman (ATL), PASSING CMP: 26.75
# Player PLAYER_Adam Froman (ATL), PASSING ATT: 37.82
# Player PLAYER_Adam Froman (ATL), PASSING PCT: 70.51
# Player PLAYER_Adam Froman (ATL), PASSING YDS: 351.25
# Player PLAYER_Adam Froman (ATL), PASSING Y/A: 9.54
# Player PLAYER_Adam Froman (ATL), PASSING TD: 3.02
# Player PLAYER_Adam Froman (ATL), PASSING INT: 0.48
# Player PLAYER_Adam Froman (ATL), PASSING SACKS: 1.58
# Player PLAYER_Adam Froman (ATL), RUSHING ATT: 5.37
# Player PLAYER_Adam Froman (ATL), RUSHING YDS: 25.79
# Player PLAYER_Adam Froman (ATL), RUSHING TD: 0.40
# Player PLAYER_Adam Froman (ATL), MISC FL: 0.26
# Player PLAYER_Adam Froman (ATL), MISC FPTS: 30.24
# Player PLAYER_Adam Froman (ATL), MISC FPTS/G: 30.24
# Player PLAYER_Adam Froman (ATL), WEEK : 2.96
# Player PLAYER_Aidan O'Connell (LV), PASSING CMP: 26.75
# Player PLAYER_Aidan O'Connell (LV), PASSING ATT: 37.82
# Player PLAYER_Aidan O'Connell (LV), PASSING PCT: 70.51
# Player PLAYER_Aidan O'Connell (LV), PASSING YDS: 351.25
# Player PLAYER_Aidan O'Connell (LV), PASSING Y/A: 9.54
# Player PLAYER_Aidan O'Connell (LV), PASSING TD: 3.02
# Player PLAYER_Aidan O'Connell (LV), PASSING INT: 0.48
# Player PLAYER_Aidan O'Connell (LV), PASSING SACKS: 1.58
# Player PLAYER_Aidan O'Connell (LV), RUSHING ATT: 5.37
# Player PLAYER_Aidan O'Connell (LV), RUSHING YDS: 25.79
# Player PLAYER_Aidan O'Connell (LV), RUSHING TD: 0.40
# Player PLAYER_Aidan O'Connell (LV), MISC FL: 0.26
# Player PLAYER_Aidan O'Connell (LV), MISC FPTS: 30.24
# Player PLAYER_Aidan O'Connell (LV), MISC FPTS/G: 30.24
# Player PLAYER_Aidan O'Connell (LV), WEEK : 2.96
# Player PLAYER_Alex McGough (GB), PASSING CMP: 26.75
# Player PLAYER_Alex McGough (GB), PASSING ATT: 37.82
# Player PLAYER_Alex McGough (GB), PASSING PCT: 70.51
# Player PLAYER_Alex McGough (GB), PASSING YDS: 351.25
# Player PLAYER_Alex McGough (GB), PASSING Y/A: 9.54
# Player PLAYER_Alex McGough (GB), PASSING TD: 3.02
# Player PLAYER_Alex McGough (GB), PASSING INT: 0.48
# Player PLAYER_Alex McGough (GB), PASSING SACKS: 1.58
# Player PLAYER_Alex McGough (GB), RUSHING ATT: 5.37
# Player PLAYER_Alex McGough (GB), RUSHING YDS: 25.79
# Player PLAYER_Alex McGough (GB), RUSHING TD: 0.40
# Player PLAYER_Alex McGough (GB), MISC FL: 0.26
# Player PLAYER_Alex McGough (GB), MISC FPTS: 30.24
# Player PLAYER_Alex McGough (GB), MISC FPTS/G: 30.24
# Player PLAYER_Alex McGough (GB), WEEK : 2.96
# Player PLAYER_Andy Dalton (CAR), PASSING CMP: 26.75
# Player PLAYER_Andy Dalton (CAR), PASSING ATT: 37.82
# Player PLAYER_Andy Dalton (CAR), PASSING PCT: 70.51
# Player PLAYER_Andy Dalton (CAR), PASSING YDS: 351.25
# Player PLAYER_Andy Dalton (CAR), PASSING Y/A: 9.54
# Player PLAYER_Andy Dalton (CAR), PASSING TD: 3.02
# Player PLAYER_Andy Dalton (CAR), PASSING INT: 0.48
# Player PLAYER_Andy Dalton (CAR), PASSING SACKS: 1.58
# Player PLAYER_Andy Dalton (CAR), RUSHING ATT: 5.37
# Player PLAYER_Andy Dalton (CAR), RUSHING YDS: 25.79
# Player PLAYER_Andy Dalton (CAR), RUSHING TD: 0.40
# Player PLAYER_Andy Dalton (CAR), MISC FL: 0.26
# Player PLAYER_Andy Dalton (CAR), MISC FPTS: 30.24
# Player PLAYER_Andy Dalton (CAR), MISC FPTS/G: 30.24
# Player PLAYER_Andy Dalton (CAR), WEEK : 2.96
# Player PLAYER_Anthony Richardson (IND), PASSING CMP: 25.56
# Player PLAYER_Anthony Richardson (IND), PASSING ATT: 36.87
# Player PLAYER_Anthony Richardson (IND), PASSING PCT: 68.43
# Player PLAYER_Anthony Richardson (IND), PASSING YDS: 336.68
# Player PLAYER_Anthony Richardson (IND), PASSING Y/A: 9.31
# Player PLAYER_Anthony Richardson (IND), PASSING TD: 2.89
# Player PLAYER_Anthony Richardson (IND), PASSING INT: 0.45
# Player PLAYER_Anthony Richardson (IND), PASSING SACKS: 1.65
# Player PLAYER_Anthony Richardson (IND), RUSHING ATT: 5.75
# Player PLAYER_Anthony Richardson (IND), RUSHING YDS: 27.77
# Player PLAYER_Anthony Richardson (IND), RUSHING TD: 0.45
# Player PLAYER_Anthony Richardson (IND), MISC FL: 0.31
# Player PLAYER_Anthony Richardson (IND), MISC FPTS: 29.85
# Player PLAYER_Anthony Richardson (IND), MISC FPTS/G: 29.85
# Player PLAYER_Anthony Richardson (IND), WEEK : 2.99
# Player PLAYER_Bailey Zappe (NE), PASSING CMP: 26.75
# Player PLAYER_Bailey Zappe (NE), PASSING ATT: 37.82
# Player PLAYER_Bailey Zappe (NE), PASSING PCT: 70.51
# Player PLAYER_Bailey Zappe (NE), PASSING YDS: 351.25
# Player PLAYER_Bailey Zappe (NE), PASSING Y/A: 9.54
# Player PLAYER_Bailey Zappe (NE), PASSING TD: 3.02
# Player PLAYER_Bailey Zappe (NE), PASSING INT: 0.48
# Player PLAYER_Bailey Zappe (NE), PASSING SACKS: 1.58
# Player PLAYER_Bailey Zappe (NE), RUSHING ATT: 5.37
# Player PLAYER_Bailey Zappe (NE), RUSHING YDS: 25.79
# Player PLAYER_Bailey Zappe (NE), RUSHING TD: 0.40
# Player PLAYER_Bailey Zappe (NE), MISC FL: 0.26
# Player PLAYER_Bailey Zappe (NE), MISC FPTS: 30.24
# Player PLAYER_Bailey Zappe (NE), MISC FPTS/G: 30.24
# Player PLAYER_Bailey Zappe (NE), WEEK : 2.96
# Player PLAYER_Baker Mayfield (TB), PASSING CMP: 26.59
# Player PLAYER_Baker Mayfield (TB), PASSING ATT: 37.73
# Player PLAYER_Baker Mayfield (TB), PASSING PCT: 70.27
# Player PLAYER_Baker Mayfield (TB), PASSING YDS: 343.17
# Player PLAYER_Baker Mayfield (TB), PASSING Y/A: 9.31
# Player PLAYER_Baker Mayfield (TB), PASSING TD: 2.98
# Player PLAYER_Baker Mayfield (TB), PASSING INT: 0.48
# Player PLAYER_Baker Mayfield (TB), PASSING SACKS: 1.53
# Player PLAYER_Baker Mayfield (TB), RUSHING ATT: 5.49
# Player PLAYER_Baker Mayfield (TB), RUSHING YDS: 25.07
# Player PLAYER_Baker Mayfield (TB), RUSHING TD: 0.37
# Player PLAYER_Baker Mayfield (TB), MISC FL: 0.25
# Player PLAYER_Baker Mayfield (TB), MISC FPTS: 29.49
# Player PLAYER_Baker Mayfield (TB), MISC FPTS/G: 29.49
# Player PLAYER_Baker Mayfield (TB), WEEK : 2.89
# Player PLAYER_Ben Chappell (WAS), PASSING CMP: 26.75
# Player PLAYER_Ben Chappell (WAS), PASSING ATT: 37.82
# Player PLAYER_Ben Chappell (WAS), PASSING PCT: 70.51
# Player PLAYER_Ben Chappell (WAS), PASSING YDS: 351.25
# Player PLAYER_Ben Chappell (WAS), PASSING Y/A: 9.54
# Player PLAYER_Ben Chappell (WAS), PASSING TD: 3.02
# Player PLAYER_Ben Chappell (WAS), PASSING INT: 0.48
# Player PLAYER_Ben Chappell (WAS), PASSING SACKS: 1.58
# Player PLAYER_Ben Chappell (WAS), RUSHING ATT: 5.37
# Player PLAYER_Ben Chappell (WAS), RUSHING YDS: 25.79
# Player PLAYER_Ben Chappell (WAS), RUSHING TD: 0.40
# Player PLAYER_Ben Chappell (WAS), MISC FL: 0.26
# Player PLAYER_Ben Chappell (WAS), MISC FPTS: 30.24
# Player PLAYER_Ben Chappell (WAS), MISC FPTS/G: 30.24
# Player PLAYER_Ben Chappell (WAS), WEEK : 2.96
# Player PLAYER_Ben DiNucci (DEN), PASSING CMP: 26.75
# Player PLAYER_Ben DiNucci (DEN), PASSING ATT: 37.82
# Player PLAYER_Ben DiNucci (DEN), PASSING PCT: 70.51
# Player PLAYER_Ben DiNucci (DEN), PASSING YDS: 351.25
# Player PLAYER_Ben DiNucci (DEN), PASSING Y/A: 9.54
# Player PLAYER_Ben DiNucci (DEN), PASSING TD: 3.02
# Player PLAYER_Ben DiNucci (DEN), PASSING INT: 0.48
# Player PLAYER_Ben DiNucci (DEN), PASSING SACKS: 1.58
# Player PLAYER_Ben DiNucci (DEN), RUSHING ATT: 5.37
# Player PLAYER_Ben DiNucci (DEN), RUSHING YDS: 25.79
# Player PLAYER_Ben DiNucci (DEN), RUSHING TD: 0.40
# Player PLAYER_Ben DiNucci (DEN), MISC FL: 0.26
# Player PLAYER_Ben DiNucci (DEN), MISC FPTS: 30.24
# Player PLAYER_Ben DiNucci (DEN), MISC FPTS/G: 30.24
# Player PLAYER_Ben DiNucci (DEN), WEEK : 2.96
# Player PLAYER_Blaine Gabbert (KC), PASSING CMP: 26.75
# Player PLAYER_Blaine Gabbert (KC), PASSING ATT: 37.82
# Player PLAYER_Blaine Gabbert (KC), PASSING PCT: 70.51
# Player PLAYER_Blaine Gabbert (KC), PASSING YDS: 351.25
# Player PLAYER_Blaine Gabbert (KC), PASSING Y/A: 9.54
# Player PLAYER_Blaine Gabbert (KC), PASSING TD: 3.02
# Player PLAYER_Blaine Gabbert (KC), PASSING INT: 0.48
# Player PLAYER_Blaine Gabbert (KC), PASSING SACKS: 1.58
# Player PLAYER_Blaine Gabbert (KC), RUSHING ATT: 5.37
# Player PLAYER_Blaine Gabbert (KC), RUSHING YDS: 25.79
# Player PLAYER_Blaine Gabbert (KC), RUSHING TD: 0.40
# Player PLAYER_Blaine Gabbert (KC), MISC FL: 0.26
# Player PLAYER_Blaine Gabbert (KC), MISC FPTS: 30.24
# Player PLAYER_Blaine Gabbert (KC), MISC FPTS/G: 30.24
# Player PLAYER_Blaine Gabbert (KC), WEEK : 2.96
# Player PLAYER_Brandon Allen (SF), PASSING CMP: 26.75
# Player PLAYER_Brandon Allen (SF), PASSING ATT: 37.82
# Player PLAYER_Brandon Allen (SF), PASSING PCT: 70.51
# Player PLAYER_Brandon Allen (SF), PASSING YDS: 351.25
# Player PLAYER_Brandon Allen (SF), PASSING Y/A: 9.54
# Player PLAYER_Brandon Allen (SF), PASSING TD: 3.02
# Player PLAYER_Brandon Allen (SF), PASSING INT: 0.48
# Player PLAYER_Brandon Allen (SF), PASSING SACKS: 1.58
# Player PLAYER_Brandon Allen (SF), RUSHING ATT: 5.37
# Player PLAYER_Brandon Allen (SF), RUSHING YDS: 25.79
# Player PLAYER_Brandon Allen (SF), RUSHING TD: 0.40
# Player PLAYER_Brandon Allen (SF), MISC FL: 0.26
# Player PLAYER_Brandon Allen (SF), MISC FPTS: 30.24
# Player PLAYER_Brandon Allen (SF), MISC FPTS/G: 30.24
# Player PLAYER_Brandon Allen (SF), WEEK : 2.96
# Player PLAYER_Brett Ratliff (TEN), PASSING CMP: 26.75
# Player PLAYER_Brett Ratliff (TEN), PASSING ATT: 37.82
# Player PLAYER_Brett Ratliff (TEN), PASSING PCT: 70.51
# Player PLAYER_Brett Ratliff (TEN), PASSING YDS: 351.25
# Player PLAYER_Brett Ratliff (TEN), PASSING Y/A: 9.54
# Player PLAYER_Brett Ratliff (TEN), PASSING TD: 3.02
# Player PLAYER_Brett Ratliff (TEN), PASSING INT: 0.48
# Player PLAYER_Brett Ratliff (TEN), PASSING SACKS: 1.58
# Player PLAYER_Brett Ratliff (TEN), RUSHING ATT: 5.37
# Player PLAYER_Brett Ratliff (TEN), RUSHING YDS: 25.79
# Player PLAYER_Brett Ratliff (TEN), RUSHING TD: 0.40
# Player PLAYER_Brett Ratliff (TEN), MISC FL: 0.26
# Player PLAYER_Brett Ratliff (TEN), MISC FPTS: 30.24
# Player PLAYER_Brett Ratliff (TEN), MISC FPTS/G: 30.24
# Player PLAYER_Brett Ratliff (TEN), WEEK : 2.96
# Player PLAYER_Brett Rypien (LAR), PASSING CMP: 26.75
# Player PLAYER_Brett Rypien (LAR), PASSING ATT: 37.82
# Player PLAYER_Brett Rypien (LAR), PASSING PCT: 70.51
# Player PLAYER_Brett Rypien (LAR), PASSING YDS: 351.25
# Player PLAYER_Brett Rypien (LAR), PASSING Y/A: 9.54
# Player PLAYER_Brett Rypien (LAR), PASSING TD: 3.02
# Player PLAYER_Brett Rypien (LAR), PASSING INT: 0.48
# Player PLAYER_Brett Rypien (LAR), PASSING SACKS: 1.58
# Player PLAYER_Brett Rypien (LAR), RUSHING ATT: 5.37
# Player PLAYER_Brett Rypien (LAR), RUSHING YDS: 25.79
# Player PLAYER_Brett Rypien (LAR), RUSHING TD: 0.40
# Player PLAYER_Brett Rypien (LAR), MISC FL: 0.26
# Player PLAYER_Brett Rypien (LAR), MISC FPTS: 30.24
# Player PLAYER_Brett Rypien (LAR), MISC FPTS/G: 30.24
# Player PLAYER_Brett Rypien (LAR), WEEK : 2.96
# Player PLAYER_Brett Smith (TB), PASSING CMP: 26.75
# Player PLAYER_Brett Smith (TB), PASSING ATT: 37.82
# Player PLAYER_Brett Smith (TB), PASSING PCT: 70.51
# Player PLAYER_Brett Smith (TB), PASSING YDS: 351.25
# Player PLAYER_Brett Smith (TB), PASSING Y/A: 9.54
# Player PLAYER_Brett Smith (TB), PASSING TD: 3.02
# Player PLAYER_Brett Smith (TB), PASSING INT: 0.48
# Player PLAYER_Brett Smith (TB), PASSING SACKS: 1.58
# Player PLAYER_Brett Smith (TB), RUSHING ATT: 5.37
# Player PLAYER_Brett Smith (TB), RUSHING YDS: 25.79
# Player PLAYER_Brett Smith (TB), RUSHING TD: 0.40
# Player PLAYER_Brett Smith (TB), MISC FL: 0.26
# Player PLAYER_Brett Smith (TB), MISC FPTS: 30.24
# Player PLAYER_Brett Smith (TB), MISC FPTS/G: 30.24
# Player PLAYER_Brett Smith (TB), WEEK : 2.96
# Player PLAYER_Brian Hoyer (LV), PASSING CMP: 26.75
# Player PLAYER_Brian Hoyer (LV), PASSING ATT: 37.82
# Player PLAYER_Brian Hoyer (LV), PASSING PCT: 70.51
# Player PLAYER_Brian Hoyer (LV), PASSING YDS: 351.25
# Player PLAYER_Brian Hoyer (LV), PASSING Y/A: 9.54
# Player PLAYER_Brian Hoyer (LV), PASSING TD: 3.02
# Player PLAYER_Brian Hoyer (LV), PASSING INT: 0.48
# Player PLAYER_Brian Hoyer (LV), PASSING SACKS: 1.58
# Player PLAYER_Brian Hoyer (LV), RUSHING ATT: 5.37
# Player PLAYER_Brian Hoyer (LV), RUSHING YDS: 25.79
# Player PLAYER_Brian Hoyer (LV), RUSHING TD: 0.40
# Player PLAYER_Brian Hoyer (LV), MISC FL: 0.26
# Player PLAYER_Brian Hoyer (LV), MISC FPTS: 30.24
# Player PLAYER_Brian Hoyer (LV), MISC FPTS/G: 30.24
# Player PLAYER_Brian Hoyer (LV), WEEK : 2.96
# Player PLAYER_Brock Purdy (SF), PASSING CMP: 26.52
# Player PLAYER_Brock Purdy (SF), PASSING ATT: 37.56
# Player PLAYER_Brock Purdy (SF), PASSING PCT: 70.40
# Player PLAYER_Brock Purdy (SF), PASSING YDS: 348.91
# Player PLAYER_Brock Purdy (SF), PASSING Y/A: 9.54
# Player PLAYER_Brock Purdy (SF), PASSING TD: 3.02
# Player PLAYER_Brock Purdy (SF), PASSING INT: 0.47
# Player PLAYER_Brock Purdy (SF), PASSING SACKS: 1.58
# Player PLAYER_Brock Purdy (SF), RUSHING ATT: 5.28
# Player PLAYER_Brock Purdy (SF), RUSHING YDS: 25.23
# Player PLAYER_Brock Purdy (SF), RUSHING TD: 0.39
# Player PLAYER_Brock Purdy (SF), MISC FL: 0.28
# Player PLAYER_Brock Purdy (SF), MISC FPTS: 29.99
# Player PLAYER_Brock Purdy (SF), MISC FPTS/G: 29.99
# Player PLAYER_Brock Purdy (SF), WEEK : 2.95
# Player PLAYER_Bryce Young (CAR), PASSING CMP: 26.75
# Player PLAYER_Bryce Young (CAR), PASSING ATT: 37.82
# Player PLAYER_Bryce Young (CAR), PASSING PCT: 70.51
# Player PLAYER_Bryce Young (CAR), PASSING YDS: 351.25
# Player PLAYER_Bryce Young (CAR), PASSING Y/A: 9.54
# Player PLAYER_Bryce Young (CAR), PASSING TD: 3.02
# Player PLAYER_Bryce Young (CAR), PASSING INT: 0.48
# Player PLAYER_Bryce Young (CAR), PASSING SACKS: 1.58
# Player PLAYER_Bryce Young (CAR), RUSHING ATT: 5.37
# Player PLAYER_Bryce Young (CAR), RUSHING YDS: 25.79
# Player PLAYER_Bryce Young (CAR), RUSHING TD: 0.40
# Player PLAYER_Bryce Young (CAR), MISC FL: 0.26
# Player PLAYER_Bryce Young (CAR), MISC FPTS: 30.24
# Player PLAYER_Bryce Young (CAR), MISC FPTS/G: 30.24
# Player PLAYER_Bryce Young (CAR), WEEK : 2.96
# Player PLAYER_C.J. Beathard (JAC), PASSING CMP: 26.75
# Player PLAYER_C.J. Beathard (JAC), PASSING ATT: 37.82
# Player PLAYER_C.J. Beathard (JAC), PASSING PCT: 70.51
# Player PLAYER_C.J. Beathard (JAC), PASSING YDS: 351.25
# Player PLAYER_C.J. Beathard (JAC), PASSING Y/A: 9.54
# Player PLAYER_C.J. Beathard (JAC), PASSING TD: 3.02
# Player PLAYER_C.J. Beathard (JAC), PASSING INT: 0.48
# Player PLAYER_C.J. Beathard (JAC), PASSING SACKS: 1.58
# Player PLAYER_C.J. Beathard (JAC), RUSHING ATT: 5.37
# Player PLAYER_C.J. Beathard (JAC), RUSHING YDS: 25.79
# Player PLAYER_C.J. Beathard (JAC), RUSHING TD: 0.40
# Player PLAYER_C.J. Beathard (JAC), MISC FL: 0.26
# Player PLAYER_C.J. Beathard (JAC), MISC FPTS: 30.24
# Player PLAYER_C.J. Beathard (JAC), MISC FPTS/G: 30.24
# Player PLAYER_C.J. Beathard (JAC), WEEK : 2.96
# Player PLAYER_C.J. Stroud (HOU), PASSING CMP: 26.55
# Player PLAYER_C.J. Stroud (HOU), PASSING ATT: 37.86
# Player PLAYER_C.J. Stroud (HOU), PASSING PCT: 69.89
# Player PLAYER_C.J. Stroud (HOU), PASSING YDS: 352.27
# Player PLAYER_C.J. Stroud (HOU), PASSING Y/A: 9.55
# Player PLAYER_C.J. Stroud (HOU), PASSING TD: 2.98
# Player PLAYER_C.J. Stroud (HOU), PASSING INT: 0.45
# Player PLAYER_C.J. Stroud (HOU), PASSING SACKS: 1.62
# Player PLAYER_C.J. Stroud (HOU), RUSHING ATT: 5.24
# Player PLAYER_C.J. Stroud (HOU), RUSHING YDS: 24.42
# Player PLAYER_C.J. Stroud (HOU), RUSHING TD: 0.37
# Player PLAYER_C.J. Stroud (HOU), MISC FL: 0.28
# Player PLAYER_C.J. Stroud (HOU), MISC FPTS: 29.76
# Player PLAYER_C.J. Stroud (HOU), MISC FPTS/G: 29.76
# Player PLAYER_C.J. Stroud (HOU), WEEK : 2.95
# Player PLAYER_Case Keenum (HOU), PASSING CMP: 26.75
# Player PLAYER_Case Keenum (HOU), PASSING ATT: 37.82
# Player PLAYER_Case Keenum (HOU), PASSING PCT: 70.51
# Player PLAYER_Case Keenum (HOU), PASSING YDS: 351.25
# Player PLAYER_Case Keenum (HOU), PASSING Y/A: 9.54
# Player PLAYER_Case Keenum (HOU), PASSING TD: 3.02
# Player PLAYER_Case Keenum (HOU), PASSING INT: 0.48
# Player PLAYER_Case Keenum (HOU), PASSING SACKS: 1.58
# Player PLAYER_Case Keenum (HOU), RUSHING ATT: 5.37
# Player PLAYER_Case Keenum (HOU), RUSHING YDS: 25.79
# Player PLAYER_Case Keenum (HOU), RUSHING TD: 0.40
# Player PLAYER_Case Keenum (HOU), MISC FL: 0.26
# Player PLAYER_Case Keenum (HOU), MISC FPTS: 30.24
# Player PLAYER_Case Keenum (HOU), MISC FPTS/G: 30.24
# Player PLAYER_Case Keenum (HOU), WEEK : 2.96
# Player PLAYER_Cephus Johnson III (TB), PASSING CMP: 26.75
# Player PLAYER_Cephus Johnson III (TB), PASSING ATT: 37.82
# Player PLAYER_Cephus Johnson III (TB), PASSING PCT: 70.51
# Player PLAYER_Cephus Johnson III (TB), PASSING YDS: 351.25
# Player PLAYER_Cephus Johnson III (TB), PASSING Y/A: 9.54
# Player PLAYER_Cephus Johnson III (TB), PASSING TD: 3.02
# Player PLAYER_Cephus Johnson III (TB), PASSING INT: 0.48
# Player PLAYER_Cephus Johnson III (TB), PASSING SACKS: 1.58
# Player PLAYER_Cephus Johnson III (TB), RUSHING ATT: 5.37
# Player PLAYER_Cephus Johnson III (TB), RUSHING YDS: 25.79
# Player PLAYER_Cephus Johnson III (TB), RUSHING TD: 0.40
# Player PLAYER_Cephus Johnson III (TB), MISC FL: 0.26
# Player PLAYER_Cephus Johnson III (TB), MISC FPTS: 30.24
# Player PLAYER_Cephus Johnson III (TB), MISC FPTS/G: 30.24
# Player PLAYER_Cephus Johnson III (TB), WEEK : 2.96
# Player PLAYER_Chris Oladokun (KC), PASSING CMP: 26.75
# Player PLAYER_Chris Oladokun (KC), PASSING ATT: 37.82
# Player PLAYER_Chris Oladokun (KC), PASSING PCT: 70.51
# Player PLAYER_Chris Oladokun (KC), PASSING YDS: 351.25
# Player PLAYER_Chris Oladokun (KC), PASSING Y/A: 9.54
# Player PLAYER_Chris Oladokun (KC), PASSING TD: 3.02
# Player PLAYER_Chris Oladokun (KC), PASSING INT: 0.48
# Player PLAYER_Chris Oladokun (KC), PASSING SACKS: 1.58
# Player PLAYER_Chris Oladokun (KC), RUSHING ATT: 5.37
# Player PLAYER_Chris Oladokun (KC), RUSHING YDS: 25.79
# Player PLAYER_Chris Oladokun (KC), RUSHING TD: 0.40
# Player PLAYER_Chris Oladokun (KC), MISC FL: 0.26
# Player PLAYER_Chris Oladokun (KC), MISC FPTS: 30.24
# Player PLAYER_Chris Oladokun (KC), MISC FPTS/G: 30.24
# Player PLAYER_Chris Oladokun (KC), WEEK : 2.96
# Player PLAYER_Clayton Tune (ARI), PASSING CMP: 26.75
# Player PLAYER_Clayton Tune (ARI), PASSING ATT: 37.82
# Player PLAYER_Clayton Tune (ARI), PASSING PCT: 70.51
# Player PLAYER_Clayton Tune (ARI), PASSING YDS: 351.25
# Player PLAYER_Clayton Tune (ARI), PASSING Y/A: 9.54
# Player PLAYER_Clayton Tune (ARI), PASSING TD: 3.02
# Player PLAYER_Clayton Tune (ARI), PASSING INT: 0.48
# Player PLAYER_Clayton Tune (ARI), PASSING SACKS: 1.58
# Player PLAYER_Clayton Tune (ARI), RUSHING ATT: 5.37
# Player PLAYER_Clayton Tune (ARI), RUSHING YDS: 25.79
# Player PLAYER_Clayton Tune (ARI), RUSHING TD: 0.40
# Player PLAYER_Clayton Tune (ARI), MISC FL: 0.26
# Player PLAYER_Clayton Tune (ARI), MISC FPTS: 30.24
# Player PLAYER_Clayton Tune (ARI), MISC FPTS/G: 30.24
# Player PLAYER_Clayton Tune (ARI), WEEK : 2.96
# Player PLAYER_Cooper Rush (DAL), PASSING CMP: 26.75
# Player PLAYER_Cooper Rush (DAL), PASSING ATT: 37.82
# Player PLAYER_Cooper Rush (DAL), PASSING PCT: 70.51
# Player PLAYER_Cooper Rush (DAL), PASSING YDS: 351.25
# Player PLAYER_Cooper Rush (DAL), PASSING Y/A: 9.54
# Player PLAYER_Cooper Rush (DAL), PASSING TD: 3.02
# Player PLAYER_Cooper Rush (DAL), PASSING INT: 0.48
# Player PLAYER_Cooper Rush (DAL), PASSING SACKS: 1.58
# Player PLAYER_Cooper Rush (DAL), RUSHING ATT: 5.37
# Player PLAYER_Cooper Rush (DAL), RUSHING YDS: 25.79
# Player PLAYER_Cooper Rush (DAL), RUSHING TD: 0.40
# Player PLAYER_Cooper Rush (DAL), MISC FL: 0.26
# Player PLAYER_Cooper Rush (DAL), MISC FPTS: 30.24
# Player PLAYER_Cooper Rush (DAL), MISC FPTS/G: 30.24
# Player PLAYER_Cooper Rush (DAL), WEEK : 2.96
# Player PLAYER_Dak Prescott (DAL), PASSING CMP: 26.75
# Player PLAYER_Dak Prescott (DAL), PASSING ATT: 37.82
# Player PLAYER_Dak Prescott (DAL), PASSING PCT: 70.51
# Player PLAYER_Dak Prescott (DAL), PASSING YDS: 351.25
# Player PLAYER_Dak Prescott (DAL), PASSING Y/A: 9.54
# Player PLAYER_Dak Prescott (DAL), PASSING TD: 3.02
# Player PLAYER_Dak Prescott (DAL), PASSING INT: 0.48
# Player PLAYER_Dak Prescott (DAL), PASSING SACKS: 1.58
# Player PLAYER_Dak Prescott (DAL), RUSHING ATT: 5.37
# Player PLAYER_Dak Prescott (DAL), RUSHING YDS: 25.79
# Player PLAYER_Dak Prescott (DAL), RUSHING TD: 0.40
# Player PLAYER_Dak Prescott (DAL), MISC FL: 0.26
# Player PLAYER_Dak Prescott (DAL), MISC FPTS: 30.24
# Player PLAYER_Dak Prescott (DAL), MISC FPTS/G: 30.24
# Player PLAYER_Dak Prescott (DAL), WEEK : 2.96
# Player PLAYER_Daniel Jones (NYG), PASSING CMP: 26.75
# Player PLAYER_Daniel Jones (NYG), PASSING ATT: 37.82
# Player PLAYER_Daniel Jones (NYG), PASSING PCT: 70.51
# Player PLAYER_Daniel Jones (NYG), PASSING YDS: 351.25
# Player PLAYER_Daniel Jones (NYG), PASSING Y/A: 9.54
# Player PLAYER_Daniel Jones (NYG), PASSING TD: 3.02
# Player PLAYER_Daniel Jones (NYG), PASSING INT: 0.48
# Player PLAYER_Daniel Jones (NYG), PASSING SACKS: 1.58
# Player PLAYER_Daniel Jones (NYG), RUSHING ATT: 5.37
# Player PLAYER_Daniel Jones (NYG), RUSHING YDS: 25.79
# Player PLAYER_Daniel Jones (NYG), RUSHING TD: 0.40
# Player PLAYER_Daniel Jones (NYG), MISC FL: 0.26
# Player PLAYER_Daniel Jones (NYG), MISC FPTS: 30.24
# Player PLAYER_Daniel Jones (NYG), MISC FPTS/G: 30.24
# Player PLAYER_Daniel Jones (NYG), WEEK : 2.96
# Player PLAYER_David Blough (DET), PASSING CMP: 26.75
# Player PLAYER_David Blough (DET), PASSING ATT: 37.82
# Player PLAYER_David Blough (DET), PASSING PCT: 70.51
# Player PLAYER_David Blough (DET), PASSING YDS: 351.25
# Player PLAYER_David Blough (DET), PASSING Y/A: 9.54
# Player PLAYER_David Blough (DET), PASSING TD: 3.02
# Player PLAYER_David Blough (DET), PASSING INT: 0.48
# Player PLAYER_David Blough (DET), PASSING SACKS: 1.58
# Player PLAYER_David Blough (DET), RUSHING ATT: 5.37
# Player PLAYER_David Blough (DET), RUSHING YDS: 25.79
# Player PLAYER_David Blough (DET), RUSHING TD: 0.40
# Player PLAYER_David Blough (DET), MISC FL: 0.26
# Player PLAYER_David Blough (DET), MISC FPTS: 30.24
# Player PLAYER_David Blough (DET), MISC FPTS/G: 30.24
# Player PLAYER_David Blough (DET), WEEK : 2.96
# Player PLAYER_Davis Mills (HOU), PASSING CMP: 26.75
# Player PLAYER_Davis Mills (HOU), PASSING ATT: 37.82
# Player PLAYER_Davis Mills (HOU), PASSING PCT: 70.51
# Player PLAYER_Davis Mills (HOU), PASSING YDS: 351.25
# Player PLAYER_Davis Mills (HOU), PASSING Y/A: 9.54
# Player PLAYER_Davis Mills (HOU), PASSING TD: 3.02
# Player PLAYER_Davis Mills (HOU), PASSING INT: 0.48
# Player PLAYER_Davis Mills (HOU), PASSING SACKS: 1.58
# Player PLAYER_Davis Mills (HOU), RUSHING ATT: 5.37
# Player PLAYER_Davis Mills (HOU), RUSHING YDS: 25.79
# Player PLAYER_Davis Mills (HOU), RUSHING TD: 0.40
# Player PLAYER_Davis Mills (HOU), MISC FL: 0.26
# Player PLAYER_Davis Mills (HOU), MISC FPTS: 30.24
# Player PLAYER_Davis Mills (HOU), MISC FPTS/G: 30.24
# Player PLAYER_Davis Mills (HOU), WEEK : 2.96
# Player PLAYER_Derek Carr (NO), PASSING CMP: 26.75
# Player PLAYER_Derek Carr (NO), PASSING ATT: 37.82
# Player PLAYER_Derek Carr (NO), PASSING PCT: 70.51
# Player PLAYER_Derek Carr (NO), PASSING YDS: 351.25
# Player PLAYER_Derek Carr (NO), PASSING Y/A: 9.54
# Player PLAYER_Derek Carr (NO), PASSING TD: 3.02
# Player PLAYER_Derek Carr (NO), PASSING INT: 0.48
# Player PLAYER_Derek Carr (NO), PASSING SACKS: 1.58
# Player PLAYER_Derek Carr (NO), RUSHING ATT: 5.37
# Player PLAYER_Derek Carr (NO), RUSHING YDS: 25.79
# Player PLAYER_Derek Carr (NO), RUSHING TD: 0.40
# Player PLAYER_Derek Carr (NO), MISC FL: 0.26
# Player PLAYER_Derek Carr (NO), MISC FPTS: 30.24
# Player PLAYER_Derek Carr (NO), MISC FPTS/G: 30.24
# Player PLAYER_Derek Carr (NO), WEEK : 2.96
# Player PLAYER_Deshaun Watson (CLE), PASSING CMP: 26.13
# Player PLAYER_Deshaun Watson (CLE), PASSING ATT: 37.29
# Player PLAYER_Deshaun Watson (CLE), PASSING PCT: 69.66
# Player PLAYER_Deshaun Watson (CLE), PASSING YDS: 340.58
# Player PLAYER_Deshaun Watson (CLE), PASSING Y/A: 9.30
# Player PLAYER_Deshaun Watson (CLE), PASSING TD: 2.90
# Player PLAYER_Deshaun Watson (CLE), PASSING INT: 0.50
# Player PLAYER_Deshaun Watson (CLE), PASSING SACKS: 1.66
# Player PLAYER_Deshaun Watson (CLE), RUSHING ATT: 5.34
# Player PLAYER_Deshaun Watson (CLE), RUSHING YDS: 26.36
# Player PLAYER_Deshaun Watson (CLE), RUSHING TD: 0.41
# Player PLAYER_Deshaun Watson (CLE), MISC FL: 0.26
# Player PLAYER_Deshaun Watson (CLE), MISC FPTS: 29.54
# Player PLAYER_Deshaun Watson (CLE), MISC FPTS/G: 29.54
# Player PLAYER_Deshaun Watson (CLE), WEEK : 2.85
# Player PLAYER_Desmond Ridder (ATL), PASSING CMP: 26.75
# Player PLAYER_Desmond Ridder (ATL), PASSING ATT: 37.82
# Player PLAYER_Desmond Ridder (ATL), PASSING PCT: 70.51
# Player PLAYER_Desmond Ridder (ATL), PASSING YDS: 351.25
# Player PLAYER_Desmond Ridder (ATL), PASSING Y/A: 9.54
# Player PLAYER_Desmond Ridder (ATL), PASSING TD: 3.02
# Player PLAYER_Desmond Ridder (ATL), PASSING INT: 0.48
# Player PLAYER_Desmond Ridder (ATL), PASSING SACKS: 1.58
# Player PLAYER_Desmond Ridder (ATL), RUSHING ATT: 5.37
# Player PLAYER_Desmond Ridder (ATL), RUSHING YDS: 25.79
# Player PLAYER_Desmond Ridder (ATL), RUSHING TD: 0.40
# Player PLAYER_Desmond Ridder (ATL), MISC FL: 0.26
# Player PLAYER_Desmond Ridder (ATL), MISC FPTS: 30.24
# Player PLAYER_Desmond Ridder (ATL), MISC FPTS/G: 30.24
# Player PLAYER_Desmond Ridder (ATL), WEEK : 2.96
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING CMP: 26.75
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING ATT: 37.82
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING PCT: 70.51
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING YDS: 351.25
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING Y/A: 9.54
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING TD: 3.02
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING INT: 0.48
# Player PLAYER_Dorian Thompson-Robinson (CLE), PASSING SACKS: 1.58
# Player PLAYER_Dorian Thompson-Robinson (CLE), RUSHING ATT: 5.37
# Player PLAYER_Dorian Thompson-Robinson (CLE), RUSHING YDS: 25.79
# Player PLAYER_Dorian Thompson-Robinson (CLE), RUSHING TD: 0.40
# Player PLAYER_Dorian Thompson-Robinson (CLE), MISC FL: 0.26
# Player PLAYER_Dorian Thompson-Robinson (CLE), MISC FPTS: 30.24
# Player PLAYER_Dorian Thompson-Robinson (CLE), MISC FPTS/G: 30.24
# Player PLAYER_Dorian Thompson-Robinson (CLE), WEEK : 2.96
# Player PLAYER_Drew Lock (SEA), PASSING CMP: 26.75
# Player PLAYER_Drew Lock (SEA), PASSING ATT: 37.82
# Player PLAYER_Drew Lock (SEA), PASSING PCT: 70.51
# Player PLAYER_Drew Lock (SEA), PASSING YDS: 351.25
# Player PLAYER_Drew Lock (SEA), PASSING Y/A: 9.54
# Player PLAYER_Drew Lock (SEA), PASSING TD: 3.02
# Player PLAYER_Drew Lock (SEA), PASSING INT: 0.48
# Player PLAYER_Drew Lock (SEA), PASSING SACKS: 1.58
# Player PLAYER_Drew Lock (SEA), RUSHING ATT: 5.37
# Player PLAYER_Drew Lock (SEA), RUSHING YDS: 25.79
# Player PLAYER_Drew Lock (SEA), RUSHING TD: 0.40
# Player PLAYER_Drew Lock (SEA), MISC FL: 0.26
# Player PLAYER_Drew Lock (SEA), MISC FPTS: 30.24
# Player PLAYER_Drew Lock (SEA), MISC FPTS/G: 30.24
# Player PLAYER_Drew Lock (SEA), WEEK : 2.96
# Player PLAYER_Easton Stick (LAC), PASSING CMP: 26.75
# Player PLAYER_Easton Stick (LAC), PASSING ATT: 37.82
# Player PLAYER_Easton Stick (LAC), PASSING PCT: 70.51
# Player PLAYER_Easton Stick (LAC), PASSING YDS: 351.25
# Player PLAYER_Easton Stick (LAC), PASSING Y/A: 9.54
# Player PLAYER_Easton Stick (LAC), PASSING TD: 3.02
# Player PLAYER_Easton Stick (LAC), PASSING INT: 0.48
# Player PLAYER_Easton Stick (LAC), PASSING SACKS: 1.58
# Player PLAYER_Easton Stick (LAC), RUSHING ATT: 5.37
# Player PLAYER_Easton Stick (LAC), RUSHING YDS: 25.79
# Player PLAYER_Easton Stick (LAC), RUSHING TD: 0.40
# Player PLAYER_Easton Stick (LAC), MISC FL: 0.26
# Player PLAYER_Easton Stick (LAC), MISC FPTS: 30.24
# Player PLAYER_Easton Stick (LAC), MISC FPTS/G: 30.24
# Player PLAYER_Easton Stick (LAC), WEEK : 2.96
# Player PLAYER_Erik Ainge (NYJ), PASSING CMP: 26.75
# Player PLAYER_Erik Ainge (NYJ), PASSING ATT: 37.82
# Player PLAYER_Erik Ainge (NYJ), PASSING PCT: 70.51
# Player PLAYER_Erik Ainge (NYJ), PASSING YDS: 351.25
# Player PLAYER_Erik Ainge (NYJ), PASSING Y/A: 9.54
# Player PLAYER_Erik Ainge (NYJ), PASSING TD: 3.02
# Player PLAYER_Erik Ainge (NYJ), PASSING INT: 0.48
# Player PLAYER_Erik Ainge (NYJ), PASSING SACKS: 1.58
# Player PLAYER_Erik Ainge (NYJ), RUSHING ATT: 5.37
# Player PLAYER_Erik Ainge (NYJ), RUSHING YDS: 25.79
# Player PLAYER_Erik Ainge (NYJ), RUSHING TD: 0.40
# Player PLAYER_Erik Ainge (NYJ), MISC FL: 0.26
# Player PLAYER_Erik Ainge (NYJ), MISC FPTS: 30.24
# Player PLAYER_Erik Ainge (NYJ), MISC FPTS/G: 30.24
# Player PLAYER_Erik Ainge (NYJ), WEEK : 2.96
# Player PLAYER_Feleipe Franks (ATL), PASSING CMP: 26.75
# Player PLAYER_Feleipe Franks (ATL), PASSING ATT: 37.82
# Player PLAYER_Feleipe Franks (ATL), PASSING PCT: 70.51
# Player PLAYER_Feleipe Franks (ATL), PASSING YDS: 351.25
# Player PLAYER_Feleipe Franks (ATL), PASSING Y/A: 9.54
# Player PLAYER_Feleipe Franks (ATL), PASSING TD: 3.02
# Player PLAYER_Feleipe Franks (ATL), PASSING INT: 0.48
# Player PLAYER_Feleipe Franks (ATL), PASSING SACKS: 1.58
# Player PLAYER_Feleipe Franks (ATL), RUSHING ATT: 5.37
# Player PLAYER_Feleipe Franks (ATL), RUSHING YDS: 25.79
# Player PLAYER_Feleipe Franks (ATL), RUSHING TD: 0.40
# Player PLAYER_Feleipe Franks (ATL), MISC FL: 0.26
# Player PLAYER_Feleipe Franks (ATL), MISC FPTS: 30.24
# Player PLAYER_Feleipe Franks (ATL), MISC FPTS/G: 30.24
# Player PLAYER_Feleipe Franks (ATL), WEEK : 2.96
# Player PLAYER_Gardner Minshew II (IND), PASSING CMP: 26.75
# Player PLAYER_Gardner Minshew II (IND), PASSING ATT: 37.82
# Player PLAYER_Gardner Minshew II (IND), PASSING PCT: 70.51
# Player PLAYER_Gardner Minshew II (IND), PASSING YDS: 351.25
# Player PLAYER_Gardner Minshew II (IND), PASSING Y/A: 9.54
# Player PLAYER_Gardner Minshew II (IND), PASSING TD: 3.02
# Player PLAYER_Gardner Minshew II (IND), PASSING INT: 0.48
# Player PLAYER_Gardner Minshew II (IND), PASSING SACKS: 1.58
# Player PLAYER_Gardner Minshew II (IND), RUSHING ATT: 5.37
# Player PLAYER_Gardner Minshew II (IND), RUSHING YDS: 25.79
# Player PLAYER_Gardner Minshew II (IND), RUSHING TD: 0.40
# Player PLAYER_Gardner Minshew II (IND), MISC FL: 0.26
# Player PLAYER_Gardner Minshew II (IND), MISC FPTS: 30.24
# Player PLAYER_Gardner Minshew II (IND), MISC FPTS/G: 30.24
# Player PLAYER_Gardner Minshew II (IND), WEEK : 2.96
# Player PLAYER_Geno Smith (SEA), PASSING CMP: 26.75
# Player PLAYER_Geno Smith (SEA), PASSING ATT: 37.82
# Player PLAYER_Geno Smith (SEA), PASSING PCT: 70.51
# Player PLAYER_Geno Smith (SEA), PASSING YDS: 351.25
# Player PLAYER_Geno Smith (SEA), PASSING Y/A: 9.54
# Player PLAYER_Geno Smith (SEA), PASSING TD: 3.02
# Player PLAYER_Geno Smith (SEA), PASSING INT: 0.48
# Player PLAYER_Geno Smith (SEA), PASSING SACKS: 1.58
# Player PLAYER_Geno Smith (SEA), RUSHING ATT: 5.37
# Player PLAYER_Geno Smith (SEA), RUSHING YDS: 25.79
# Player PLAYER_Geno Smith (SEA), RUSHING TD: 0.40
# Player PLAYER_Geno Smith (SEA), MISC FL: 0.26
# Player PLAYER_Geno Smith (SEA), MISC FPTS: 30.24
# Player PLAYER_Geno Smith (SEA), MISC FPTS/G: 30.24
# Player PLAYER_Geno Smith (SEA), WEEK : 2.96
# Player PLAYER_Hendon Hooker (DET), PASSING CMP: 26.75
# Player PLAYER_Hendon Hooker (DET), PASSING ATT: 37.82
# Player PLAYER_Hendon Hooker (DET), PASSING PCT: 70.51
# Player PLAYER_Hendon Hooker (DET), PASSING YDS: 351.25
# Player PLAYER_Hendon Hooker (DET), PASSING Y/A: 9.54
# Player PLAYER_Hendon Hooker (DET), PASSING TD: 3.02
# Player PLAYER_Hendon Hooker (DET), PASSING INT: 0.48
# Player PLAYER_Hendon Hooker (DET), PASSING SACKS: 1.58
# Player PLAYER_Hendon Hooker (DET), RUSHING ATT: 5.37
# Player PLAYER_Hendon Hooker (DET), RUSHING YDS: 25.79
# Player PLAYER_Hendon Hooker (DET), RUSHING TD: 0.40
# Player PLAYER_Hendon Hooker (DET), MISC FL: 0.26
# Player PLAYER_Hendon Hooker (DET), MISC FPTS: 30.24
# Player PLAYER_Hendon Hooker (DET), MISC FPTS/G: 30.24
# Player PLAYER_Hendon Hooker (DET), WEEK : 2.96
# Player PLAYER_Holton Ahlers (SEA), PASSING CMP: 26.75
# Player PLAYER_Holton Ahlers (SEA), PASSING ATT: 37.82
# Player PLAYER_Holton Ahlers (SEA), PASSING PCT: 70.51
# Player PLAYER_Holton Ahlers (SEA), PASSING YDS: 351.25
# Player PLAYER_Holton Ahlers (SEA), PASSING Y/A: 9.54
# Player PLAYER_Holton Ahlers (SEA), PASSING TD: 3.02
# Player PLAYER_Holton Ahlers (SEA), PASSING INT: 0.48
# Player PLAYER_Holton Ahlers (SEA), PASSING SACKS: 1.58
# Player PLAYER_Holton Ahlers (SEA), RUSHING ATT: 5.37
# Player PLAYER_Holton Ahlers (SEA), RUSHING YDS: 25.79
# Player PLAYER_Holton Ahlers (SEA), RUSHING TD: 0.40
# Player PLAYER_Holton Ahlers (SEA), MISC FL: 0.26
# Player PLAYER_Holton Ahlers (SEA), MISC FPTS: 30.24
# Player PLAYER_Holton Ahlers (SEA), MISC FPTS/G: 30.24
# Player PLAYER_Holton Ahlers (SEA), WEEK : 2.96
# Player PLAYER_Hunter Cantwell (BAL), PASSING CMP: 26.75
# Player PLAYER_Hunter Cantwell (BAL), PASSING ATT: 37.82
# Player PLAYER_Hunter Cantwell (BAL), PASSING PCT: 70.51
# Player PLAYER_Hunter Cantwell (BAL), PASSING YDS: 351.25
# Player PLAYER_Hunter Cantwell (BAL), PASSING Y/A: 9.54
# Player PLAYER_Hunter Cantwell (BAL), PASSING TD: 3.02
# Player PLAYER_Hunter Cantwell (BAL), PASSING INT: 0.48
# Player PLAYER_Hunter Cantwell (BAL), PASSING SACKS: 1.58
# Player PLAYER_Hunter Cantwell (BAL), RUSHING ATT: 5.37
# Player PLAYER_Hunter Cantwell (BAL), RUSHING YDS: 25.79
# Player PLAYER_Hunter Cantwell (BAL), RUSHING TD: 0.40
# Player PLAYER_Hunter Cantwell (BAL), MISC FL: 0.26
# Player PLAYER_Hunter Cantwell (BAL), MISC FPTS: 30.24
# Player PLAYER_Hunter Cantwell (BAL), MISC FPTS/G: 30.24
# Player PLAYER_Hunter Cantwell (BAL), WEEK : 2.96
# Player PLAYER_Jacoby Brissett (WAS), PASSING CMP: 26.75
# Player PLAYER_Jacoby Brissett (WAS), PASSING ATT: 37.82
# Player PLAYER_Jacoby Brissett (WAS), PASSING PCT: 70.51
# Player PLAYER_Jacoby Brissett (WAS), PASSING YDS: 351.25
# Player PLAYER_Jacoby Brissett (WAS), PASSING Y/A: 9.54
# Player PLAYER_Jacoby Brissett (WAS), PASSING TD: 3.02
# Player PLAYER_Jacoby Brissett (WAS), PASSING INT: 0.48
# Player PLAYER_Jacoby Brissett (WAS), PASSING SACKS: 1.58
# Player PLAYER_Jacoby Brissett (WAS), RUSHING ATT: 5.37
# Player PLAYER_Jacoby Brissett (WAS), RUSHING YDS: 25.79
# Player PLAYER_Jacoby Brissett (WAS), RUSHING TD: 0.40
# Player PLAYER_Jacoby Brissett (WAS), MISC FL: 0.26
# Player PLAYER_Jacoby Brissett (WAS), MISC FPTS: 30.24
# Player PLAYER_Jacoby Brissett (WAS), MISC FPTS/G: 30.24
# Player PLAYER_Jacoby Brissett (WAS), WEEK : 2.96
# Player PLAYER_Jake Browning (CIN), PASSING CMP: 26.75
# Player PLAYER_Jake Browning (CIN), PASSING ATT: 37.82
# Player PLAYER_Jake Browning (CIN), PASSING PCT: 70.51
# Player PLAYER_Jake Browning (CIN), PASSING YDS: 351.25
# Player PLAYER_Jake Browning (CIN), PASSING Y/A: 9.54
# Player PLAYER_Jake Browning (CIN), PASSING TD: 3.02
# Player PLAYER_Jake Browning (CIN), PASSING INT: 0.48
# Player PLAYER_Jake Browning (CIN), PASSING SACKS: 1.58
# Player PLAYER_Jake Browning (CIN), RUSHING ATT: 5.37
# Player PLAYER_Jake Browning (CIN), RUSHING YDS: 25.79
# Player PLAYER_Jake Browning (CIN), RUSHING TD: 0.40
# Player PLAYER_Jake Browning (CIN), MISC FL: 0.26
# Player PLAYER_Jake Browning (CIN), MISC FPTS: 30.24
# Player PLAYER_Jake Browning (CIN), MISC FPTS/G: 30.24
# Player PLAYER_Jake Browning (CIN), WEEK : 2.96
# Player PLAYER_Jake Fromm (WAS), PASSING CMP: 26.75
# Player PLAYER_Jake Fromm (WAS), PASSING ATT: 37.82
# Player PLAYER_Jake Fromm (WAS), PASSING PCT: 70.51
# Player PLAYER_Jake Fromm (WAS), PASSING YDS: 351.25
# Player PLAYER_Jake Fromm (WAS), PASSING Y/A: 9.54
# Player PLAYER_Jake Fromm (WAS), PASSING TD: 3.02
# Player PLAYER_Jake Fromm (WAS), PASSING INT: 0.48
# Player PLAYER_Jake Fromm (WAS), PASSING SACKS: 1.58
# Player PLAYER_Jake Fromm (WAS), RUSHING ATT: 5.37
# Player PLAYER_Jake Fromm (WAS), RUSHING YDS: 25.79
# Player PLAYER_Jake Fromm (WAS), RUSHING TD: 0.40
# Player PLAYER_Jake Fromm (WAS), MISC FL: 0.26
# Player PLAYER_Jake Fromm (WAS), MISC FPTS: 30.24
# Player PLAYER_Jake Fromm (WAS), MISC FPTS/G: 30.24
# Player PLAYER_Jake Fromm (WAS), WEEK : 2.96
# Player PLAYER_Jake Haener (NO), PASSING CMP: 26.75
# Player PLAYER_Jake Haener (NO), PASSING ATT: 37.82
# Player PLAYER_Jake Haener (NO), PASSING PCT: 70.51
# Player PLAYER_Jake Haener (NO), PASSING YDS: 351.25
# Player PLAYER_Jake Haener (NO), PASSING Y/A: 9.54
# Player PLAYER_Jake Haener (NO), PASSING TD: 3.02
# Player PLAYER_Jake Haener (NO), PASSING INT: 0.48
# Player PLAYER_Jake Haener (NO), PASSING SACKS: 1.58
# Player PLAYER_Jake Haener (NO), RUSHING ATT: 5.37
# Player PLAYER_Jake Haener (NO), RUSHING YDS: 25.79
# Player PLAYER_Jake Haener (NO), RUSHING TD: 0.40
# Player PLAYER_Jake Haener (NO), MISC FL: 0.26
# Player PLAYER_Jake Haener (NO), MISC FPTS: 30.24
# Player PLAYER_Jake Haener (NO), MISC FPTS/G: 30.24
# Player PLAYER_Jake Haener (NO), WEEK : 2.96
# Player PLAYER_Jake Luton (NO), PASSING CMP: 26.75
# Player PLAYER_Jake Luton (NO), PASSING ATT: 37.82
# Player PLAYER_Jake Luton (NO), PASSING PCT: 70.51
# Player PLAYER_Jake Luton (NO), PASSING YDS: 351.25
# Player PLAYER_Jake Luton (NO), PASSING Y/A: 9.54
# Player PLAYER_Jake Luton (NO), PASSING TD: 3.02
# Player PLAYER_Jake Luton (NO), PASSING INT: 0.48
# Player PLAYER_Jake Luton (NO), PASSING SACKS: 1.58
# Player PLAYER_Jake Luton (NO), RUSHING ATT: 5.37
# Player PLAYER_Jake Luton (NO), RUSHING YDS: 25.79
# Player PLAYER_Jake Luton (NO), RUSHING TD: 0.40
# Player PLAYER_Jake Luton (NO), MISC FL: 0.26
# Player PLAYER_Jake Luton (NO), MISC FPTS: 30.24
# Player PLAYER_Jake Luton (NO), MISC FPTS/G: 30.24
# Player PLAYER_Jake Luton (NO), WEEK : 2.96
# Player PLAYER_Jalen Hurts (PHI), PASSING CMP: 26.58
# Player PLAYER_Jalen Hurts (PHI), PASSING ATT: 37.68
# Player PLAYER_Jalen Hurts (PHI), PASSING PCT: 70.32
# Player PLAYER_Jalen Hurts (PHI), PASSING YDS: 349.85
# Player PLAYER_Jalen Hurts (PHI), PASSING Y/A: 9.51
# Player PLAYER_Jalen Hurts (PHI), PASSING TD: 2.96
# Player PLAYER_Jalen Hurts (PHI), PASSING INT: 0.49
# Player PLAYER_Jalen Hurts (PHI), PASSING SACKS: 1.61
# Player PLAYER_Jalen Hurts (PHI), RUSHING ATT: 5.69
# Player PLAYER_Jalen Hurts (PHI), RUSHING YDS: 26.85
# Player PLAYER_Jalen Hurts (PHI), RUSHING TD: 0.41
# Player PLAYER_Jalen Hurts (PHI), MISC FL: 0.26
# Player PLAYER_Jalen Hurts (PHI), MISC FPTS: 30.13
# Player PLAYER_Jalen Hurts (PHI), MISC FPTS/G: 30.13
# Player PLAYER_Jalen Hurts (PHI), WEEK : 2.99
# Player PLAYER_Jameis Winston (NO), PASSING CMP: 26.75
# Player PLAYER_Jameis Winston (NO), PASSING ATT: 37.82
# Player PLAYER_Jameis Winston (NO), PASSING PCT: 70.51
# Player PLAYER_Jameis Winston (NO), PASSING YDS: 351.25
# Player PLAYER_Jameis Winston (NO), PASSING Y/A: 9.54
# Player PLAYER_Jameis Winston (NO), PASSING TD: 3.02
# Player PLAYER_Jameis Winston (NO), PASSING INT: 0.48
# Player PLAYER_Jameis Winston (NO), PASSING SACKS: 1.58
# Player PLAYER_Jameis Winston (NO), RUSHING ATT: 5.37
# Player PLAYER_Jameis Winston (NO), RUSHING YDS: 25.79
# Player PLAYER_Jameis Winston (NO), RUSHING TD: 0.40
# Player PLAYER_Jameis Winston (NO), MISC FL: 0.26
# Player PLAYER_Jameis Winston (NO), MISC FPTS: 30.24
# Player PLAYER_Jameis Winston (NO), MISC FPTS/G: 30.24
# Player PLAYER_Jameis Winston (NO), WEEK : 2.96
# Player PLAYER_Jared Goff (DET), PASSING CMP: 26.75
# Player PLAYER_Jared Goff (DET), PASSING ATT: 37.82
# Player PLAYER_Jared Goff (DET), PASSING PCT: 70.51
# Player PLAYER_Jared Goff (DET), PASSING YDS: 351.25
# Player PLAYER_Jared Goff (DET), PASSING Y/A: 9.54
# Player PLAYER_Jared Goff (DET), PASSING TD: 3.02
# Player PLAYER_Jared Goff (DET), PASSING INT: 0.48
# Player PLAYER_Jared Goff (DET), PASSING SACKS: 1.58
# Player PLAYER_Jared Goff (DET), RUSHING ATT: 5.37
# Player PLAYER_Jared Goff (DET), RUSHING YDS: 25.79
# Player PLAYER_Jared Goff (DET), RUSHING TD: 0.40
# Player PLAYER_Jared Goff (DET), MISC FL: 0.26
# Player PLAYER_Jared Goff (DET), MISC FPTS: 30.24
# Player PLAYER_Jared Goff (DET), MISC FPTS/G: 30.24
# Player PLAYER_Jared Goff (DET), WEEK : 2.96
# Player PLAYER_Jaren Hall (MIN), PASSING CMP: 26.75
# Player PLAYER_Jaren Hall (MIN), PASSING ATT: 37.82
# Player PLAYER_Jaren Hall (MIN), PASSING PCT: 70.51
# Player PLAYER_Jaren Hall (MIN), PASSING YDS: 351.25
# Player PLAYER_Jaren Hall (MIN), PASSING Y/A: 9.54
# Player PLAYER_Jaren Hall (MIN), PASSING TD: 3.02
# Player PLAYER_Jaren Hall (MIN), PASSING INT: 0.48
# Player PLAYER_Jaren Hall (MIN), PASSING SACKS: 1.58
# Player PLAYER_Jaren Hall (MIN), RUSHING ATT: 5.37
# Player PLAYER_Jaren Hall (MIN), RUSHING YDS: 25.79
# Player PLAYER_Jaren Hall (MIN), RUSHING TD: 0.40
# Player PLAYER_Jaren Hall (MIN), MISC FL: 0.26
# Player PLAYER_Jaren Hall (MIN), MISC FPTS: 30.24
# Player PLAYER_Jaren Hall (MIN), MISC FPTS/G: 30.24
# Player PLAYER_Jaren Hall (MIN), WEEK : 2.96
# Player PLAYER_Jarrett Stidham (DEN), PASSING CMP: 26.75
# Player PLAYER_Jarrett Stidham (DEN), PASSING ATT: 37.82
# Player PLAYER_Jarrett Stidham (DEN), PASSING PCT: 70.51
# Player PLAYER_Jarrett Stidham (DEN), PASSING YDS: 351.25
# Player PLAYER_Jarrett Stidham (DEN), PASSING Y/A: 9.54
# Player PLAYER_Jarrett Stidham (DEN), PASSING TD: 3.02
# Player PLAYER_Jarrett Stidham (DEN), PASSING INT: 0.48
# Player PLAYER_Jarrett Stidham (DEN), PASSING SACKS: 1.58
# Player PLAYER_Jarrett Stidham (DEN), RUSHING ATT: 5.37
# Player PLAYER_Jarrett Stidham (DEN), RUSHING YDS: 25.79
# Player PLAYER_Jarrett Stidham (DEN), RUSHING TD: 0.40
# Player PLAYER_Jarrett Stidham (DEN), MISC FL: 0.26
# Player PLAYER_Jarrett Stidham (DEN), MISC FPTS: 30.24
# Player PLAYER_Jarrett Stidham (DEN), MISC FPTS/G: 30.24
# Player PLAYER_Jarrett Stidham (DEN), WEEK : 2.96
# Player PLAYER_Jeff Driskel (ARI), PASSING CMP: 26.75
# Player PLAYER_Jeff Driskel (ARI), PASSING ATT: 37.82
# Player PLAYER_Jeff Driskel (ARI), PASSING PCT: 70.51
# Player PLAYER_Jeff Driskel (ARI), PASSING YDS: 351.25
# Player PLAYER_Jeff Driskel (ARI), PASSING Y/A: 9.54
# Player PLAYER_Jeff Driskel (ARI), PASSING TD: 3.02
# Player PLAYER_Jeff Driskel (ARI), PASSING INT: 0.48
# Player PLAYER_Jeff Driskel (ARI), PASSING SACKS: 1.58
# Player PLAYER_Jeff Driskel (ARI), RUSHING ATT: 5.37
# Player PLAYER_Jeff Driskel (ARI), RUSHING YDS: 25.79
# Player PLAYER_Jeff Driskel (ARI), RUSHING TD: 0.40
# Player PLAYER_Jeff Driskel (ARI), MISC FL: 0.26
# Player PLAYER_Jeff Driskel (ARI), MISC FPTS: 30.24
# Player PLAYER_Jeff Driskel (ARI), MISC FPTS/G: 30.24
# Player PLAYER_Jeff Driskel (ARI), WEEK : 2.96
# Player PLAYER_Jimmy Garoppolo (LV), PASSING CMP: 26.75
# Player PLAYER_Jimmy Garoppolo (LV), PASSING ATT: 37.82
# Player PLAYER_Jimmy Garoppolo (LV), PASSING PCT: 70.51
# Player PLAYER_Jimmy Garoppolo (LV), PASSING YDS: 351.25
# Player PLAYER_Jimmy Garoppolo (LV), PASSING Y/A: 9.54
# Player PLAYER_Jimmy Garoppolo (LV), PASSING TD: 3.02
# Player PLAYER_Jimmy Garoppolo (LV), PASSING INT: 0.48
# Player PLAYER_Jimmy Garoppolo (LV), PASSING SACKS: 1.58
# Player PLAYER_Jimmy Garoppolo (LV), RUSHING ATT: 5.37
# Player PLAYER_Jimmy Garoppolo (LV), RUSHING YDS: 25.79
# Player PLAYER_Jimmy Garoppolo (LV), RUSHING TD: 0.40
# Player PLAYER_Jimmy Garoppolo (LV), MISC FL: 0.26
# Player PLAYER_Jimmy Garoppolo (LV), MISC FPTS: 30.24
# Player PLAYER_Jimmy Garoppolo (LV), MISC FPTS/G: 30.24
# Player PLAYER_Jimmy Garoppolo (LV), WEEK : 2.96
# Player PLAYER_Joe Burrow (CIN), PASSING CMP: 26.75
# Player PLAYER_Joe Burrow (CIN), PASSING ATT: 37.82
# Player PLAYER_Joe Burrow (CIN), PASSING PCT: 70.51
# Player PLAYER_Joe Burrow (CIN), PASSING YDS: 351.25
# Player PLAYER_Joe Burrow (CIN), PASSING Y/A: 9.54
# Player PLAYER_Joe Burrow (CIN), PASSING TD: 3.02
# Player PLAYER_Joe Burrow (CIN), PASSING INT: 0.48
# Player PLAYER_Joe Burrow (CIN), PASSING SACKS: 1.58
# Player PLAYER_Joe Burrow (CIN), RUSHING ATT: 5.37
# Player PLAYER_Joe Burrow (CIN), RUSHING YDS: 25.79
# Player PLAYER_Joe Burrow (CIN), RUSHING TD: 0.40
# Player PLAYER_Joe Burrow (CIN), MISC FL: 0.26
# Player PLAYER_Joe Burrow (CIN), MISC FPTS: 30.24
# Player PLAYER_Joe Burrow (CIN), MISC FPTS/G: 30.24
# Player PLAYER_Joe Burrow (CIN), WEEK : 2.96
# Player PLAYER_John Wolford (TB), PASSING CMP: 26.75
# Player PLAYER_John Wolford (TB), PASSING ATT: 37.82
# Player PLAYER_John Wolford (TB), PASSING PCT: 70.51
# Player PLAYER_John Wolford (TB), PASSING YDS: 351.25
# Player PLAYER_John Wolford (TB), PASSING Y/A: 9.54
# Player PLAYER_John Wolford (TB), PASSING TD: 3.02
# Player PLAYER_John Wolford (TB), PASSING INT: 0.48
# Player PLAYER_John Wolford (TB), PASSING SACKS: 1.58
# Player PLAYER_John Wolford (TB), RUSHING ATT: 5.37
# Player PLAYER_John Wolford (TB), RUSHING YDS: 25.79
# Player PLAYER_John Wolford (TB), RUSHING TD: 0.40
# Player PLAYER_John Wolford (TB), MISC FL: 0.26
# Player PLAYER_John Wolford (TB), MISC FPTS: 30.24
# Player PLAYER_John Wolford (TB), MISC FPTS/G: 30.24
# Player PLAYER_John Wolford (TB), WEEK : 2.96
# Player PLAYER_Jordan Love (GB), PASSING CMP: 26.75
# Player PLAYER_Jordan Love (GB), PASSING ATT: 37.82
# Player PLAYER_Jordan Love (GB), PASSING PCT: 70.51
# Player PLAYER_Jordan Love (GB), PASSING YDS: 351.25
# Player PLAYER_Jordan Love (GB), PASSING Y/A: 9.54
# Player PLAYER_Jordan Love (GB), PASSING TD: 3.02
# Player PLAYER_Jordan Love (GB), PASSING INT: 0.48
# Player PLAYER_Jordan Love (GB), PASSING SACKS: 1.58
# Player PLAYER_Jordan Love (GB), RUSHING ATT: 5.37
# Player PLAYER_Jordan Love (GB), RUSHING YDS: 25.79
# Player PLAYER_Jordan Love (GB), RUSHING TD: 0.40
# Player PLAYER_Jordan Love (GB), MISC FL: 0.26
# Player PLAYER_Jordan Love (GB), MISC FPTS: 30.24
# Player PLAYER_Jordan Love (GB), MISC FPTS/G: 30.24
# Player PLAYER_Jordan Love (GB), WEEK : 2.96
# Player PLAYER_Josh Allen (BUF), PASSING CMP: 26.83
# Player PLAYER_Josh Allen (BUF), PASSING ATT: 37.90
# Player PLAYER_Josh Allen (BUF), PASSING PCT: 70.60
# Player PLAYER_Josh Allen (BUF), PASSING YDS: 352.47
# Player PLAYER_Josh Allen (BUF), PASSING Y/A: 9.56
# Player PLAYER_Josh Allen (BUF), PASSING TD: 3.01
# Player PLAYER_Josh Allen (BUF), PASSING INT: 0.49
# Player PLAYER_Josh Allen (BUF), PASSING SACKS: 1.55
# Player PLAYER_Josh Allen (BUF), RUSHING ATT: 5.29
# Player PLAYER_Josh Allen (BUF), RUSHING YDS: 25.23
# Player PLAYER_Josh Allen (BUF), RUSHING TD: 0.41
# Player PLAYER_Josh Allen (BUF), MISC FL: 0.26
# Player PLAYER_Josh Allen (BUF), MISC FPTS: 30.27
# Player PLAYER_Josh Allen (BUF), MISC FPTS/G: 30.27
# Player PLAYER_Josh Allen (BUF), WEEK : 2.99
# Player PLAYER_Josh Johnson (BAL), PASSING CMP: 26.75
# Player PLAYER_Josh Johnson (BAL), PASSING ATT: 37.82
# Player PLAYER_Josh Johnson (BAL), PASSING PCT: 70.51
# Player PLAYER_Josh Johnson (BAL), PASSING YDS: 351.25
# Player PLAYER_Josh Johnson (BAL), PASSING Y/A: 9.54
# Player PLAYER_Josh Johnson (BAL), PASSING TD: 3.02
# Player PLAYER_Josh Johnson (BAL), PASSING INT: 0.48
# Player PLAYER_Josh Johnson (BAL), PASSING SACKS: 1.58
# Player PLAYER_Josh Johnson (BAL), RUSHING ATT: 5.37
# Player PLAYER_Josh Johnson (BAL), RUSHING YDS: 25.79
# Player PLAYER_Josh Johnson (BAL), RUSHING TD: 0.40
# Player PLAYER_Josh Johnson (BAL), MISC FL: 0.26
# Player PLAYER_Josh Johnson (BAL), MISC FPTS: 30.24
# Player PLAYER_Josh Johnson (BAL), MISC FPTS/G: 30.24
# Player PLAYER_Josh Johnson (BAL), WEEK : 2.96
# Player PLAYER_Joshua Dobbs (ARI), PASSING CMP: 26.67
# Player PLAYER_Joshua Dobbs (ARI), PASSING ATT: 37.60
# Player PLAYER_Joshua Dobbs (ARI), PASSING PCT: 70.77
# Player PLAYER_Joshua Dobbs (ARI), PASSING YDS: 349.43
# Player PLAYER_Joshua Dobbs (ARI), PASSING Y/A: 9.54
# Player PLAYER_Joshua Dobbs (ARI), PASSING TD: 2.99
# Player PLAYER_Joshua Dobbs (ARI), PASSING INT: 0.47
# Player PLAYER_Joshua Dobbs (ARI), PASSING SACKS: 1.57
# Player PLAYER_Joshua Dobbs (ARI), RUSHING ATT: 5.29
# Player PLAYER_Joshua Dobbs (ARI), RUSHING YDS: 25.88
# Player PLAYER_Joshua Dobbs (ARI), RUSHING TD: 0.39
# Player PLAYER_Joshua Dobbs (ARI), MISC FL: 0.26
# Player PLAYER_Joshua Dobbs (ARI), MISC FPTS: 30.03
# ...
# Player PLAYER_Sam Howell (WAS), RUSHING TD: 0.39
# Player PLAYER_Sam Howell (WAS), MISC FL: 0.26
# Player PLAYER_Sam Howell (WAS), MISC FPTS: 30.08
# Player PLAYER_Sam Howell (WAS), MISC FPTS/G: 30.08
# Player PLAYER_Sam Howell (WAS), WEEK : 2.96
# Player PLAYER_Sean Clifford (GB), PASSING CMP: 26.75
# Player PLAYER_Sean Clifford (GB), PASSING ATT: 37.82
# Player PLAYER_Sean Clifford (GB), PASSING PCT: 70.51
# Player PLAYER_Sean Clifford (GB), PASSING YDS: 351.25
# Player PLAYER_Sean Clifford (GB), PASSING Y/A: 9.54
# Player PLAYER_Sean Clifford (GB), PASSING TD: 3.02
# Player PLAYER_Sean Clifford (GB), PASSING INT: 0.48
# Player PLAYER_Sean Clifford (GB), PASSING SACKS: 1.58
# Player PLAYER_Sean Clifford (GB), RUSHING ATT: 5.37
# Player PLAYER_Sean Clifford (GB), RUSHING YDS: 25.79
# Player PLAYER_Sean Clifford (GB), RUSHING TD: 0.40
# Player PLAYER_Sean Clifford (GB), MISC FL: 0.26
# Player PLAYER_Sean Clifford (GB), MISC FPTS: 30.24
# Player PLAYER_Sean Clifford (GB), MISC FPTS/G: 30.24
# Player PLAYER_Sean Clifford (GB), WEEK : 2.96
# Player PLAYER_Sean Mannion (MIN), PASSING CMP: 26.75
# Player PLAYER_Sean Mannion (MIN), PASSING ATT: 37.82
# Player PLAYER_Sean Mannion (MIN), PASSING PCT: 70.51
# Player PLAYER_Sean Mannion (MIN), PASSING YDS: 351.25
# Player PLAYER_Sean Mannion (MIN), PASSING Y/A: 9.54
# Player PLAYER_Sean Mannion (MIN), PASSING TD: 3.02
# Player PLAYER_Sean Mannion (MIN), PASSING INT: 0.48
# Player PLAYER_Sean Mannion (MIN), PASSING SACKS: 1.58
# Player PLAYER_Sean Mannion (MIN), RUSHING ATT: 5.37
# Player PLAYER_Sean Mannion (MIN), RUSHING YDS: 25.79
# Player PLAYER_Sean Mannion (MIN), RUSHING TD: 0.40
# Player PLAYER_Sean Mannion (MIN), MISC FL: 0.26
# Player PLAYER_Sean Mannion (MIN), MISC FPTS: 30.24
# Player PLAYER_Sean Mannion (MIN), MISC FPTS/G: 30.24
# Player PLAYER_Sean Mannion (MIN), WEEK : 2.96
# Player PLAYER_Shane Buechele (BUF), PASSING CMP: 26.75
# Player PLAYER_Shane Buechele (BUF), PASSING ATT: 37.82
# Player PLAYER_Shane Buechele (BUF), PASSING PCT: 70.51
# Player PLAYER_Shane Buechele (BUF), PASSING YDS: 351.25
# Player PLAYER_Shane Buechele (BUF), PASSING Y/A: 9.54
# Player PLAYER_Shane Buechele (BUF), PASSING TD: 3.02
# Player PLAYER_Shane Buechele (BUF), PASSING INT: 0.48
# Player PLAYER_Shane Buechele (BUF), PASSING SACKS: 1.58
# Player PLAYER_Shane Buechele (BUF), RUSHING ATT: 5.37
# Player PLAYER_Shane Buechele (BUF), RUSHING YDS: 25.79
# Player PLAYER_Shane Buechele (BUF), RUSHING TD: 0.40
# Player PLAYER_Shane Buechele (BUF), MISC FL: 0.26
# Player PLAYER_Shane Buechele (BUF), MISC FPTS: 30.24
# Player PLAYER_Shane Buechele (BUF), MISC FPTS/G: 30.24
# Player PLAYER_Shane Buechele (BUF), WEEK : 2.96
# Player PLAYER_Skylar Thompson (MIA), PASSING CMP: 26.75
# Player PLAYER_Skylar Thompson (MIA), PASSING ATT: 37.82
# Player PLAYER_Skylar Thompson (MIA), PASSING PCT: 70.51
# Player PLAYER_Skylar Thompson (MIA), PASSING YDS: 351.25
# Player PLAYER_Skylar Thompson (MIA), PASSING Y/A: 9.54
# Player PLAYER_Skylar Thompson (MIA), PASSING TD: 3.02
# Player PLAYER_Skylar Thompson (MIA), PASSING INT: 0.48
# Player PLAYER_Skylar Thompson (MIA), PASSING SACKS: 1.58
# Player PLAYER_Skylar Thompson (MIA), RUSHING ATT: 5.37
# Player PLAYER_Skylar Thompson (MIA), RUSHING YDS: 25.79
# Player PLAYER_Skylar Thompson (MIA), RUSHING TD: 0.40
# Player PLAYER_Skylar Thompson (MIA), MISC FL: 0.26
# Player PLAYER_Skylar Thompson (MIA), MISC FPTS: 30.24
# Player PLAYER_Skylar Thompson (MIA), MISC FPTS/G: 30.24
# Player PLAYER_Skylar Thompson (MIA), WEEK : 2.96
# Player PLAYER_Stetson Bennett (LAR), PASSING CMP: 26.75
# Player PLAYER_Stetson Bennett (LAR), PASSING ATT: 37.82
# Player PLAYER_Stetson Bennett (LAR), PASSING PCT: 70.51
# Player PLAYER_Stetson Bennett (LAR), PASSING YDS: 351.25
# Player PLAYER_Stetson Bennett (LAR), PASSING Y/A: 9.54
# Player PLAYER_Stetson Bennett (LAR), PASSING TD: 3.02
# Player PLAYER_Stetson Bennett (LAR), PASSING INT: 0.48
# Player PLAYER_Stetson Bennett (LAR), PASSING SACKS: 1.58
# Player PLAYER_Stetson Bennett (LAR), RUSHING ATT: 5.37
# Player PLAYER_Stetson Bennett (LAR), RUSHING YDS: 25.79
# Player PLAYER_Stetson Bennett (LAR), RUSHING TD: 0.40
# Player PLAYER_Stetson Bennett (LAR), MISC FL: 0.26
# Player PLAYER_Stetson Bennett (LAR), MISC FPTS: 30.24
# Player PLAYER_Stetson Bennett (LAR), MISC FPTS/G: 30.24
# Player PLAYER_Stetson Bennett (LAR), WEEK : 2.96
# Player PLAYER_Tanner McKee (PHI), PASSING CMP: 26.75
# Player PLAYER_Tanner McKee (PHI), PASSING ATT: 37.82
# Player PLAYER_Tanner McKee (PHI), PASSING PCT: 70.51
# Player PLAYER_Tanner McKee (PHI), PASSING YDS: 351.25
# Player PLAYER_Tanner McKee (PHI), PASSING Y/A: 9.54
# Player PLAYER_Tanner McKee (PHI), PASSING TD: 3.02
# Player PLAYER_Tanner McKee (PHI), PASSING INT: 0.48
# Player PLAYER_Tanner McKee (PHI), PASSING SACKS: 1.58
# Player PLAYER_Tanner McKee (PHI), RUSHING ATT: 5.37
# Player PLAYER_Tanner McKee (PHI), RUSHING YDS: 25.79
# Player PLAYER_Tanner McKee (PHI), RUSHING TD: 0.40
# Player PLAYER_Tanner McKee (PHI), MISC FL: 0.26
# Player PLAYER_Tanner McKee (PHI), MISC FPTS: 30.24
# Player PLAYER_Tanner McKee (PHI), MISC FPTS/G: 30.24
# Player PLAYER_Tanner McKee (PHI), WEEK : 2.96
# Player PLAYER_Taylor Heinicke (ATL), PASSING CMP: 26.75
# Player PLAYER_Taylor Heinicke (ATL), PASSING ATT: 37.82
# Player PLAYER_Taylor Heinicke (ATL), PASSING PCT: 70.51
# Player PLAYER_Taylor Heinicke (ATL), PASSING YDS: 351.25
# Player PLAYER_Taylor Heinicke (ATL), PASSING Y/A: 9.54
# Player PLAYER_Taylor Heinicke (ATL), PASSING TD: 3.02
# Player PLAYER_Taylor Heinicke (ATL), PASSING INT: 0.48
# Player PLAYER_Taylor Heinicke (ATL), PASSING SACKS: 1.58
# Player PLAYER_Taylor Heinicke (ATL), RUSHING ATT: 5.37
# Player PLAYER_Taylor Heinicke (ATL), RUSHING YDS: 25.79
# Player PLAYER_Taylor Heinicke (ATL), RUSHING TD: 0.40
# Player PLAYER_Taylor Heinicke (ATL), MISC FL: 0.26
# Player PLAYER_Taylor Heinicke (ATL), MISC FPTS: 30.24
# Player PLAYER_Taylor Heinicke (ATL), MISC FPTS/G: 30.24
# Player PLAYER_Taylor Heinicke (ATL), WEEK : 2.96
# Player PLAYER_Teddy Bridgewater (DET), PASSING CMP: 26.75
# Player PLAYER_Teddy Bridgewater (DET), PASSING ATT: 37.82
# Player PLAYER_Teddy Bridgewater (DET), PASSING PCT: 70.51
# Player PLAYER_Teddy Bridgewater (DET), PASSING YDS: 351.25
# Player PLAYER_Teddy Bridgewater (DET), PASSING Y/A: 9.54
# Player PLAYER_Teddy Bridgewater (DET), PASSING TD: 3.02
# Player PLAYER_Teddy Bridgewater (DET), PASSING INT: 0.48
# Player PLAYER_Teddy Bridgewater (DET), PASSING SACKS: 1.58
# Player PLAYER_Teddy Bridgewater (DET), RUSHING ATT: 5.37
# Player PLAYER_Teddy Bridgewater (DET), RUSHING YDS: 25.79
# Player PLAYER_Teddy Bridgewater (DET), RUSHING TD: 0.40
# Player PLAYER_Teddy Bridgewater (DET), MISC FL: 0.26
# Player PLAYER_Teddy Bridgewater (DET), MISC FPTS: 30.24
# Player PLAYER_Teddy Bridgewater (DET), MISC FPTS/G: 30.24
# Player PLAYER_Teddy Bridgewater (DET), WEEK : 2.96
# Player PLAYER_Tim Boyle (NYJ), PASSING CMP: 26.75
# Player PLAYER_Tim Boyle (NYJ), PASSING ATT: 37.82
# Player PLAYER_Tim Boyle (NYJ), PASSING PCT: 70.51
# Player PLAYER_Tim Boyle (NYJ), PASSING YDS: 351.25
# Player PLAYER_Tim Boyle (NYJ), PASSING Y/A: 9.54
# Player PLAYER_Tim Boyle (NYJ), PASSING TD: 3.02
# Player PLAYER_Tim Boyle (NYJ), PASSING INT: 0.48
# Player PLAYER_Tim Boyle (NYJ), PASSING SACKS: 1.58
# Player PLAYER_Tim Boyle (NYJ), RUSHING ATT: 5.37
# Player PLAYER_Tim Boyle (NYJ), RUSHING YDS: 25.79
# Player PLAYER_Tim Boyle (NYJ), RUSHING TD: 0.40
# Player PLAYER_Tim Boyle (NYJ), MISC FL: 0.26
# Player PLAYER_Tim Boyle (NYJ), MISC FPTS: 30.24
# Player PLAYER_Tim Boyle (NYJ), MISC FPTS/G: 30.24
# Player PLAYER_Tim Boyle (NYJ), WEEK : 2.96
# Player PLAYER_Tommy DeVito (NYG), PASSING CMP: 26.75
# Player PLAYER_Tommy DeVito (NYG), PASSING ATT: 37.82
# Player PLAYER_Tommy DeVito (NYG), PASSING PCT: 70.51
# Player PLAYER_Tommy DeVito (NYG), PASSING YDS: 351.25
# Player PLAYER_Tommy DeVito (NYG), PASSING Y/A: 9.54
# Player PLAYER_Tommy DeVito (NYG), PASSING TD: 3.02
# Player PLAYER_Tommy DeVito (NYG), PASSING INT: 0.48
# Player PLAYER_Tommy DeVito (NYG), PASSING SACKS: 1.58
# Player PLAYER_Tommy DeVito (NYG), RUSHING ATT: 5.37
# Player PLAYER_Tommy DeVito (NYG), RUSHING YDS: 25.79
# Player PLAYER_Tommy DeVito (NYG), RUSHING TD: 0.40
# Player PLAYER_Tommy DeVito (NYG), MISC FL: 0.26
# Player PLAYER_Tommy DeVito (NYG), MISC FPTS: 30.24
# Player PLAYER_Tommy DeVito (NYG), MISC FPTS/G: 30.24
# Player PLAYER_Tommy DeVito (NYG), WEEK : 2.96
# Player PLAYER_Trevor Lawrence (JAC), PASSING CMP: 26.75
# Player PLAYER_Trevor Lawrence (JAC), PASSING ATT: 37.82
# Player PLAYER_Trevor Lawrence (JAC), PASSING PCT: 70.51
# Player PLAYER_Trevor Lawrence (JAC), PASSING YDS: 351.25
# Player PLAYER_Trevor Lawrence (JAC), PASSING Y/A: 9.54
# Player PLAYER_Trevor Lawrence (JAC), PASSING TD: 3.02
# Player PLAYER_Trevor Lawrence (JAC), PASSING INT: 0.48
# Player PLAYER_Trevor Lawrence (JAC), PASSING SACKS: 1.58
# Player PLAYER_Trevor Lawrence (JAC), RUSHING ATT: 5.37
# Player PLAYER_Trevor Lawrence (JAC), RUSHING YDS: 25.79
# Player PLAYER_Trevor Lawrence (JAC), RUSHING TD: 0.40
# Player PLAYER_Trevor Lawrence (JAC), MISC FL: 0.26
# Player PLAYER_Trevor Lawrence (JAC), MISC FPTS: 30.24
# Player PLAYER_Trevor Lawrence (JAC), MISC FPTS/G: 30.24
# Player PLAYER_Trevor Lawrence (JAC), WEEK : 2.96
# Player PLAYER_Trevor Siemian (NYJ), PASSING CMP: 26.75
# Player PLAYER_Trevor Siemian (NYJ), PASSING ATT: 37.82
# Player PLAYER_Trevor Siemian (NYJ), PASSING PCT: 70.51
# Player PLAYER_Trevor Siemian (NYJ), PASSING YDS: 351.25
# Player PLAYER_Trevor Siemian (NYJ), PASSING Y/A: 9.54
# Player PLAYER_Trevor Siemian (NYJ), PASSING TD: 3.02
# Player PLAYER_Trevor Siemian (NYJ), PASSING INT: 0.48
# Player PLAYER_Trevor Siemian (NYJ), PASSING SACKS: 1.58
# Player PLAYER_Trevor Siemian (NYJ), RUSHING ATT: 5.37
# Player PLAYER_Trevor Siemian (NYJ), RUSHING YDS: 25.79
# Player PLAYER_Trevor Siemian (NYJ), RUSHING TD: 0.40
# Player PLAYER_Trevor Siemian (NYJ), MISC FL: 0.26
# Player PLAYER_Trevor Siemian (NYJ), MISC FPTS: 30.24
# Player PLAYER_Trevor Siemian (NYJ), MISC FPTS/G: 30.24
# Player PLAYER_Trevor Siemian (NYJ), WEEK : 2.96
# Player PLAYER_Trey Lance (DAL), PASSING CMP: 26.75
# Player PLAYER_Trey Lance (DAL), PASSING ATT: 37.82
# Player PLAYER_Trey Lance (DAL), PASSING PCT: 70.51
# Player PLAYER_Trey Lance (DAL), PASSING YDS: 351.25
# Player PLAYER_Trey Lance (DAL), PASSING Y/A: 9.54
# Player PLAYER_Trey Lance (DAL), PASSING TD: 3.02
# Player PLAYER_Trey Lance (DAL), PASSING INT: 0.48
# Player PLAYER_Trey Lance (DAL), PASSING SACKS: 1.58
# Player PLAYER_Trey Lance (DAL), RUSHING ATT: 5.37
# Player PLAYER_Trey Lance (DAL), RUSHING YDS: 25.79
# Player PLAYER_Trey Lance (DAL), RUSHING TD: 0.40
# Player PLAYER_Trey Lance (DAL), MISC FL: 0.26
# Player PLAYER_Trey Lance (DAL), MISC FPTS: 30.24
# Player PLAYER_Trey Lance (DAL), MISC FPTS/G: 30.24
# Player PLAYER_Trey Lance (DAL), WEEK : 2.96
# Player PLAYER_Tua Tagovailoa (MIA), PASSING CMP: 26.84
# Player PLAYER_Tua Tagovailoa (MIA), PASSING ATT: 37.67
# Player PLAYER_Tua Tagovailoa (MIA), PASSING PCT: 71.41
# Player PLAYER_Tua Tagovailoa (MIA), PASSING YDS: 355.94
# Player PLAYER_Tua Tagovailoa (MIA), PASSING Y/A: 9.71
# Player PLAYER_Tua Tagovailoa (MIA), PASSING TD: 3.05
# Player PLAYER_Tua Tagovailoa (MIA), PASSING INT: 0.50
# Player PLAYER_Tua Tagovailoa (MIA), PASSING SACKS: 1.44
# Player PLAYER_Tua Tagovailoa (MIA), RUSHING ATT: 4.98
# Player PLAYER_Tua Tagovailoa (MIA), RUSHING YDS: 23.05
# Player PLAYER_Tua Tagovailoa (MIA), RUSHING TD: 0.36
# Player PLAYER_Tua Tagovailoa (MIA), MISC FL: 0.27
# Player PLAYER_Tua Tagovailoa (MIA), MISC FPTS: 29.94
# Player PLAYER_Tua Tagovailoa (MIA), MISC FPTS/G: 29.94
# Player PLAYER_Tua Tagovailoa (MIA), WEEK : 2.86
# Player PLAYER_Tyler Huntley (BAL), PASSING CMP: 26.75
# Player PLAYER_Tyler Huntley (BAL), PASSING ATT: 37.82
# Player PLAYER_Tyler Huntley (BAL), PASSING PCT: 70.51
# Player PLAYER_Tyler Huntley (BAL), PASSING YDS: 351.25
# Player PLAYER_Tyler Huntley (BAL), PASSING Y/A: 9.54
# Player PLAYER_Tyler Huntley (BAL), PASSING TD: 3.02
# Player PLAYER_Tyler Huntley (BAL), PASSING INT: 0.48
# Player PLAYER_Tyler Huntley (BAL), PASSING SACKS: 1.58
# Player PLAYER_Tyler Huntley (BAL), RUSHING ATT: 5.37
# Player PLAYER_Tyler Huntley (BAL), RUSHING YDS: 25.79
# Player PLAYER_Tyler Huntley (BAL), RUSHING TD: 0.40
# Player PLAYER_Tyler Huntley (BAL), MISC FL: 0.26
# Player PLAYER_Tyler Huntley (BAL), MISC FPTS: 30.24
# Player PLAYER_Tyler Huntley (BAL), MISC FPTS/G: 30.24
# Player PLAYER_Tyler Huntley (BAL), WEEK : 2.96
# Player PLAYER_Tyrod Taylor (NYG), PASSING CMP: 26.75
# Player PLAYER_Tyrod Taylor (NYG), PASSING ATT: 37.82
# Player PLAYER_Tyrod Taylor (NYG), PASSING PCT: 70.51
# Player PLAYER_Tyrod Taylor (NYG), PASSING YDS: 351.25
# Player PLAYER_Tyrod Taylor (NYG), PASSING Y/A: 9.54
# Player PLAYER_Tyrod Taylor (NYG), PASSING TD: 3.02
# Player PLAYER_Tyrod Taylor (NYG), PASSING INT: 0.48
# Player PLAYER_Tyrod Taylor (NYG), PASSING SACKS: 1.58
# Player PLAYER_Tyrod Taylor (NYG), RUSHING ATT: 5.37
# Player PLAYER_Tyrod Taylor (NYG), RUSHING YDS: 25.79
# Player PLAYER_Tyrod Taylor (NYG), RUSHING TD: 0.40
# Player PLAYER_Tyrod Taylor (NYG), MISC FL: 0.26
# Player PLAYER_Tyrod Taylor (NYG), MISC FPTS: 30.24
# Player PLAYER_Tyrod Taylor (NYG), MISC FPTS/G: 30.24
# Player PLAYER_Tyrod Taylor (NYG), WEEK : 2.96
# Player PLAYER_Tyson Bagent (CHI), PASSING CMP: 26.75
# Player PLAYER_Tyson Bagent (CHI), PASSING ATT: 37.82
# Player PLAYER_Tyson Bagent (CHI), PASSING PCT: 70.51
# Player PLAYER_Tyson Bagent (CHI), PASSING YDS: 351.25
# Player PLAYER_Tyson Bagent (CHI), PASSING Y/A: 9.54
# Player PLAYER_Tyson Bagent (CHI), PASSING TD: 3.02
# Player PLAYER_Tyson Bagent (CHI), PASSING INT: 0.48
# Player PLAYER_Tyson Bagent (CHI), PASSING SACKS: 1.58
# Player PLAYER_Tyson Bagent (CHI), RUSHING ATT: 5.37
# Player PLAYER_Tyson Bagent (CHI), RUSHING YDS: 25.79
# Player PLAYER_Tyson Bagent (CHI), RUSHING TD: 0.40
# Player PLAYER_Tyson Bagent (CHI), MISC FL: 0.26
# Player PLAYER_Tyson Bagent (CHI), MISC FPTS: 30.24
# Player PLAYER_Tyson Bagent (CHI), MISC FPTS/G: 30.24
# Player PLAYER_Tyson Bagent (CHI), WEEK : 2.96
# Player PLAYER_Will Grier (NE), PASSING CMP: 26.75
# Player PLAYER_Will Grier (NE), PASSING ATT: 37.82
# Player PLAYER_Will Grier (NE), PASSING PCT: 70.51
# Player PLAYER_Will Grier (NE), PASSING YDS: 351.25
# Player PLAYER_Will Grier (NE), PASSING Y/A: 9.54
# Player PLAYER_Will Grier (NE), PASSING TD: 3.02
# Player PLAYER_Will Grier (NE), PASSING INT: 0.48
# Player PLAYER_Will Grier (NE), PASSING SACKS: 1.58
# Player PLAYER_Will Grier (NE), RUSHING ATT: 5.37
# Player PLAYER_Will Grier (NE), RUSHING YDS: 25.79
# Player PLAYER_Will Grier (NE), RUSHING TD: 0.40
# Player PLAYER_Will Grier (NE), MISC FL: 0.26
# Player PLAYER_Will Grier (NE), MISC FPTS: 30.24
# Player PLAYER_Will Grier (NE), MISC FPTS/G: 30.24
# Player PLAYER_Will Grier (NE), WEEK : 2.96
# Player PLAYER_Will Levis (TEN), PASSING CMP: 26.75
# Player PLAYER_Will Levis (TEN), PASSING ATT: 37.82
# Player PLAYER_Will Levis (TEN), PASSING PCT: 70.51
# Player PLAYER_Will Levis (TEN), PASSING YDS: 351.25
# Player PLAYER_Will Levis (TEN), PASSING Y/A: 9.54
# Player PLAYER_Will Levis (TEN), PASSING TD: 3.02
# Player PLAYER_Will Levis (TEN), PASSING INT: 0.48
# Player PLAYER_Will Levis (TEN), PASSING SACKS: 1.58
# Player PLAYER_Will Levis (TEN), RUSHING ATT: 5.37
# Player PLAYER_Will Levis (TEN), RUSHING YDS: 25.79
# Player PLAYER_Will Levis (TEN), RUSHING TD: 0.40
# Player PLAYER_Will Levis (TEN), MISC FL: 0.26
# Player PLAYER_Will Levis (TEN), MISC FPTS: 30.24
# Player PLAYER_Will Levis (TEN), MISC FPTS/G: 30.24
# Player PLAYER_Will Levis (TEN), WEEK : 2.96
# Player PLAYER_Zach Wilson (NYJ), PASSING CMP: 26.75
# Player PLAYER_Zach Wilson (NYJ), PASSING ATT: 37.82
# Player PLAYER_Zach Wilson (NYJ), PASSING PCT: 70.51
# Player PLAYER_Zach Wilson (NYJ), PASSING YDS: 351.25
# Player PLAYER_Zach Wilson (NYJ), PASSING Y/A: 9.54
# Player PLAYER_Zach Wilson (NYJ), PASSING TD: 3.02
# Player PLAYER_Zach Wilson (NYJ), PASSING INT: 0.48
# Player PLAYER_Zach Wilson (NYJ), PASSING SACKS: 1.58
# Player PLAYER_Zach Wilson (NYJ), RUSHING ATT: 5.37
# Player PLAYER_Zach Wilson (NYJ), RUSHING YDS: 25.79
# Player PLAYER_Zach Wilson (NYJ), RUSHING TD: 0.40
# Player PLAYER_Zach Wilson (NYJ), MISC FL: 0.26
# Player PLAYER_Zach Wilson (NYJ), MISC FPTS: 30.24
# Player PLAYER_Zach Wilson (NYJ), MISC FPTS/G: 30.24
# Player PLAYER_Zach Wilson (NYJ), WEEK : 2.96

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer

# Load your dataset
data = pd.read_csv("datasets/weekly_scoring.csv")

# Preprocessing
data = data[data['POS'] == 'qb']
data = data.drop(columns=['POS RANK', 'POS', 'MISC G', 'MISC ROST', 'MISC FPTS/G', 'RECEIVING REC', 'RECEIVING TGT', 'RECEIVING YDS', 'RECEIVING Y/R',
 'RECEIVING LG', 'RECEIVING 20+', 'RECEIVING TD', 'RUSHING Y/A', 'RUSHING LG',
 'RUSHING 20+'])
data = pd.get_dummies(data, columns=['PLAYER'], drop_first=True)

# Identify columns with missing values before imputation
columns_with_missing = data.columns[data.isnull().any()].tolist()

# Impute missing values with the mean of each column
imputer = SimpleImputer(strategy='mean')
data = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# Define the list of variables to predict
var_list = ['PASSING CMP', 'PASSING ATT', 'PASSING PCT', 'PASSING YDS', 'PASSING Y/A', 'PASSING TD', 'PASSING INT',
            'PASSING SACKS', 'RUSHING ATT', 'RUSHING YDS', 'RUSHING TD', 'MISC FL', 'MISC FPTS', 'WEEK ']

# Separate the dataset into features (X) and the target variable (y)
X = data.drop(var_list, axis=1)
y = data['MISC FPTS']

# Save a copy of the dataset
df = data

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X, y)

# Fit the model with the best hyperparameters
best_rf_model = grid_search.best_estimator_
best_rf_model.fit(X, y)

# Get a list of unique player names after one-hot encoding
unique_players = X.columns

# Create a list of dictionaries to store the results
results_list = []

for player in unique_players:
    # Create a DataFrame with all zeros
    week6_data = pd.DataFrame(0, index=range(1), columns=X.columns)
    # Set the corresponding player's column to 1 for prediction
    week6_data[player] = 1
    # Make a prediction for the player
    misc_fpts_prediction = best_rf_model.predict(week6_data)
    results_list.append({'Player': player, 'MISC FPTS': misc_fpts_prediction[0]})

# Convert the list of dictionaries into a DataFrame
results_df = pd.DataFrame(results_list)

results_df.head(10)

# Save the results to a CSV file
# results_df.to_csv('fantasy_football_predictions.csv', index=False)
# Out:
#                             Player  MISC FPTS
# 0       PLAYER_Aaron Rodgers (NYJ)   0.000000
# 1         PLAYER_Adam Froman (ATL)   0.000000
# 2      PLAYER_Aidan O'Connell (LV)   2.178488
# 3         PLAYER_Alex McGough (GB)   0.000000
# 4         PLAYER_Andy Dalton (CAR)   4.750914
# 5  PLAYER_Anthony Richardson (IND)  15.362299
# 6         PLAYER_Bailey Zappe (NE)   0.592155
# 7       PLAYER_Baker Mayfield (TB)  13.837784
# 8        PLAYER_Ben Chappell (WAS)   0.000000
# 9         PLAYER_Ben DiNucci (DEN)   0.000000
